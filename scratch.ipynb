# %%
# %matplotlib notebook

import numpy as np
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# PARAMETERS: SET THE SIZE OF THE DATASET, THE AMOUNT OF NOISE, THE TRAIN/TEST RATIO
numData = 20
standardDeviation = 3
test_size = .5

# GENERATE DATA FROM LINEAR RELATIONSHIP: y = x + Normal_noise(mean=0, standardDeviation)
x = np.array(range(numData)).reshape((-1,1))
y = x + np.random.normal(loc=0.0, scale=standardDeviation, size=numData).reshape((-1,1))

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)

# FIT LINEAR REGRESSION
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

# PREDICT ON TEST SET
y_pred = regr.predict(x_test)

# CALCULATE R2 ON TRAIN AND TEST SETS
r2_train = r2_score(x_train,y_train)
r2_test = r2_score(x_test,y_test)

# PLOT THE DATA AND THE FITTED MODEL 
plt.figure()
plt.plot(x,y,'.')
plt.plot(x, regr.predict(x))
plt.title("R_squared train/test: " + str(r2_train) + '/' + str(r2_test));
# Out:
# <img src="data:image/png;base64,..." width="640">
