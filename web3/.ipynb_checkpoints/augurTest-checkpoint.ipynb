// %% [markdown]
// # Augur

// %%
var Augur = require('augur.js');
var augur = new Augur();

var myConnectionInfo;

var httpAddress = "https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b"
//var httpAddress = "https://rinkeby.augur.net/ethereum-http"

var ethereumNode = { 
  httpAddresses: [
    httpAddress,
  ]
};

//var augurNode = "ws://127.0.0.1:9001" // local Augur Node
var augurNode = "ws://18.208.37.82:9001" // Augur Node on my aws machine

augur.connect({ ethereumNode, augurNode }, function (err, connectionInfo) { myConnectionInfo = connectionInfo});
//var connectionInfo = augur.connect({ ethereumNode, augurNode });
// Out:
// connecting to augur-node: ws://18.208.37.82:9001
// connecting to ethereum-node: {"httpAddresses":["https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b"]}
// websocket ws://18.208.37.82:9001 opened
// connected to augur
// connected to ethereum
// [ethrpc] http-transport unexpected status code IncomingMessage {
//   _readableState:
//    ReadableState {
//      objectMode: false,
//      highWaterMark: 16384,
//      buffer: BufferList { head: null, tail: null, length: 0 },
//      length: 0,
//      pipes: null,
//      pipesCount: 0,
//      flowing: true,
//      ended: true,
//      endEmitted: true,
//      reading: false,
//      sync: true,
//      needReadable: false,
//      emittedReadable: false,
//      readableListening: false,
//      resumeScheduled: false,
//      emitClose: true,
//      destroyed: false,
//      defaultEncoding: 'utf8',
//      awaitDrain: 0,
//      readingMore: true,
//      decoder: null,
//      encoding: null },
//   readable: false,
//   _events:
//    [Object: null prototype] {
//      end:
//       [ [Function: responseOnEnd],
//         [Function],
//         { [Function: bound onceWrapper] listener: [Function] } ],
//      close: [ [Function], [Function] ],
//      data: [Function],
//      error: [Function] },
//   _eventsCount: 4,
//   _maxListeners: undefined,
//   socket:
//    TLSSocket {
//      _tlsOptions:
//       { pipe: false,
//         secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//         isServer: false,
//         requestCert: true,
//         rejectUnauthorized: true,
//         session:
//          <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes>,
//         ALPNProtocols: undefined,
//         requestOCSP: undefined },
//      _secureEstablished: true,
//      _securePending: false,
//      _newSessionPending: false,
//      _controlReleased: true,
//      _SNICallback: null,
//      servername: 'mainnet.infura.io',
//      alpnProtocol: false,
//      authorized: true,
//      authorizationError: null,
//      encrypted: true,
//      _events:
//       [Object: null prototype] {
//         close:
//          [ [Function: onSocketCloseDestroySSL],
//            { [Function: bound onceWrapper] listener: [Function] },
//            [Function: onClose],
//            [Function: socketCloseListener] ],
//         end: [Function: onReadableStreamEnd],
//         secure: [Function: onConnectSecure],
//         free: [Function: onFree],
//         agentRemove: [Function: onRemove],
//         drain: [Function: ondrain],
//         error: [Function: socketErrorListener],
//         timeout:
//          { [Function: bound onceWrapper] listener: [Function: emitRequestTimeout] },
//         finish:
//          { [Function: bound onceWrapper] listener: [Function: destroy] } },
//      _eventsCount: 9,
//      connecting: false,
//      _hadError: false,
//      _handle:
//       TLSWrap {
//         _parent:
//          TCP {
//            reading: [Getter/Setter],
//            onread: null,
//            onconnection: null,
//            [Symbol(owner)]: [Circular] },
//         _parentWrap: undefined,
//         _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//         reading: true,
//         onread: [Function: onStreamRead],
//         onhandshakestart: [Function: noop],
//         onhandshakedone: [Function: bound ],
//         onocspresponse: [Function: onocspresponse],
//         onerror: [Function: onerror],
//         [Symbol(owner)]: [Circular] },
//      _parent: null,
//      _host: 'mainnet.infura.io',
//      _readableState:
//       ReadableState {
//         objectMode: false,
//         highWaterMark: 16384,
//         buffer: BufferList { head: null, tail: null, length: 0 },
//         length: 0,
//         pipes: null,
//         pipesCount: 0,
//         flowing: true,
//         ended: false,
//         endEmitted: false,
//         reading: true,
//         sync: false,
//         needReadable: true,
//         emittedReadable: false,
//         readableListening: false,
//         resumeScheduled: false,
//         emitClose: false,
//         destroyed: false,
//         defaultEncoding: 'utf8',
//         awaitDrain: 0,
//         readingMore: false,
//         decoder: null,
//         encoding: null },
//      readable: true,
//      _maxListeners: undefined,
//      _writableState:
//       WritableState {
//         objectMode: false,
//         highWaterMark: 16384,
//         finalCalled: true,
//         needDrain: false,
//         ending: true,
//         ended: true,
//         finished: false,
//         destroyed: false,
//         decodeStrings: false,
//         defaultEncoding: 'utf8',
//         length: 0,
//         writing: false,
//         corked: 0,
//         sync: false,
//         bufferProcessing: false,
//         onwrite: [Function: bound onwrite],
//         writecb: null,
//         writelen: 0,
//         bufferedRequest: null,
//         lastBufferedRequest: null,
//         pendingcb: 1,
//         prefinished: false,
//         errorEmitted: false,
//         emitClose: false,
//         bufferedRequestCount: 0,
//         corkedRequestsFree:
//          { next:
//             { next: null,
//               entry: null,
//               finish: [Function: bound onCorkedFinish] },
//            entry: null,
//            finish: [Function: bound onCorkedFinish] } },
//      writable: false,
//      allowHalfOpen: false,
//      _sockname: null,
//      _pendingData: null,
//      _pendingEncoding: '',
//      server: undefined,
//      _server: null,
//      ssl:
//       TLSWrap {
//         _parent:
//          TCP {
//            reading: [Getter/Setter],
//            onread: null,
//            onconnection: null,
//            [Symbol(owner)]: [Circular] },
//         _parentWrap: undefined,
//         _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//         reading: true,
//         onread: [Function: onStreamRead],
//         onhandshakestart: [Function: noop],
//         onhandshakedone: [Function: bound ],
//         onocspresponse: [Function: onocspresponse],
//         onerror: [Function: onerror],
//         [Symbol(owner)]: [Circular] },
//      _requestCert: true,
//      _rejectUnauthorized: true,
//      parser: null,
//      _httpMessage:
//       ClientRequest {
//         _events:
//          [Object: null prototype] {
//            socket: [Function],
//            response: [Function: bound ],
//            error: [ [Function: bound ], [Function] ],
//            drain: [Function],
//            timeout: { [Function: bound onceWrapper] listener: [Function] },
//            prefinish: [Function: requestOnPrefinish] },
//         _eventsCount: 6,
//         _maxListeners: undefined,
//         output: [],
//         outputEncodings: [],
//         outputCallbacks: [],
//         outputSize: 0,
//         writable: true,
//         _last: true,
//         chunkedEncoding: false,
//         shouldKeepAlive: false,
//         useChunkedEncodingByDefault: true,
//         sendDate: false,
//         _removedConnection: false,
//         _removedContLen: false,
//         _removedTE: false,
//         _contentLength: null,
//         _hasBody: true,
//         _trailer: '',
//         finished: true,
//         _headerSent: true,
//         socket: [Circular],
//         connection: [Circular],
//         _header:
//          'POST /v3/f565925a6c5143188b5589a37b28139b HTTP/1.1\r\nhost: mainnet.infura.io\r\naccept: application/json\r\ncontent-type: application/json\r\ncontent-length: 74\r\nConnection: close\r\n\r\n',
//         _onPendingData: [Function: noopPendingOutput],
//         agent:
//          Agent {
//            _events: [Object: null prototype] { free: [Function] },
//            _eventsCount: 1,
//            _maxListeners: undefined,
//            defaultPort: 443,
//            protocol: 'https:',
//            options: { path: null },
//            requests: {},
//            sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//            freeSockets: {},
//            keepAliveMsecs: 1000,
//            keepAlive: false,
//            maxSockets: Infinity,
//            maxFreeSockets: 256,
//            maxCachedSessions: 100,
//            _sessionCache:
//             { map:
//                { 'mainnet.infura.io:443::::::::::::::::':
//                   <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//               list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//         socketPath: undefined,
//         timeout: undefined,
//         method: 'POST',
//         path: '/v3/f565925a6c5143188b5589a37b28139b',
//         _ended: true,
//         res: [Circular],
//         aborted: false,
//         timeoutCb: [Function: emitRequestTimeout],
//         upgradeOrConnect: false,
//         parser: null,
//         maxHeadersCount: null,
//         [Symbol(isCorked)]: false,
//         [Symbol(outHeadersKey)]:
//          [Object: null prototype] {
//            host: [ 'host', 'mainnet.infura.io' ],
//            accept: [ 'accept', 'application/json' ],
//            'content-type': [ 'content-type', 'application/json' ],
//            'content-length': [ 'content-length', 74 ] } },
//      timeout: 60000,
//      [Symbol(res)]:
//       TLSWrap {
//         _parent:
//          TCP {
//            reading: [Getter/Setter],
//            onread: null,
//            onconnection: null,
//            [Symbol(owner)]: [Circular] },
//         _parentWrap: undefined,
//         _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//         reading: true,
//         onread: [Function: onStreamRead],
//         onhandshakestart: [Function: noop],
//         onhandshakedone: [Function: bound ],
//         onocspresponse: [Function: onocspresponse],
//         onerror: [Function: onerror],
//         [Symbol(owner)]: [Circular] },
//      [Symbol(asyncId)]: 130,
//      [Symbol(lastWriteQueueSize)]: 0,
//      [Symbol(timeout)]:
//       Timeout {
//         _idleTimeout: 60000,
//         _idlePrev: [TimersList],
//         _idleNext: [TimersList],
//         _idleStart: 4851,
//         _onTimeout: [Function: bound ],
//         _timerArgs: undefined,
//         _repeat: null,
//         _destroyed: false,
//         [Symbol(refed)]: false,
//         [Symbol(asyncId)]: 140,
//         [Symbol(triggerId)]: 138 },
//      [Symbol(kBytesRead)]: 0,
//      [Symbol(kBytesWritten)]: 0,
//      [Symbol(connect-options)]:
//       { rejectUnauthorized: true,
//         ciphers:
//          'ECDHE-RSA-AES128-GCM-SHA256:ECDHE-ECDSA-AES128-GCM-SHA256:ECDHE-RSA-AES256-GCM-SHA384:ECDHE-ECDSA-AES256-GCM-SHA384:DHE-RSA-AES128-GCM-SHA256:ECDHE-RSA-AES128-SHA256:DHE-RSA-AES128-SHA256:ECDHE-RSA-AES256-SHA384:DHE-RSA-AES256-SHA384:ECDHE-RSA-AES256-SHA256:DHE-RSA-AES256-SHA256:HIGH:!aNULL:!eNULL:!EXPORT:!DES:!RC4:!MD5:!PSK:!SRP:!CAMELLIA',
//         checkServerIdentity: [Function: checkServerIdentity],
//         minDHSize: 1024,
//         servername: 'mainnet.infura.io',
//         _defaultAgent:
//          Agent {
//            _events: [Object: null prototype] { free: [Function] },
//            _eventsCount: 1,
//            _maxListeners: undefined,
//            defaultPort: 443,
//            protocol: 'https:',
//            options: { path: null },
//            requests: {},
//            sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//            freeSockets: {},
//            keepAliveMsecs: 1000,
//            keepAlive: false,
//            maxSockets: Infinity,
//            maxFreeSockets: 256,
//            maxCachedSessions: 100,
//            _sessionCache:
//             { map:
//                { 'mainnet.infura.io:443::::::::::::::::':
//                   <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//               list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//         _events:
//          [Object: null prototype] {
//            error: [Function: bound ],
//            complete: [Function: bound ],
//            pipe: [Function],
//            data: [Function],
//            end: [Function] },
//         _eventsCount: 3,
//         _maxListeners: undefined,
//         method: 'POST',
//         callback: [Function],
//         readable: true,
//         writable: true,
//         explicitMethod: true,
//         _qs:
//          Querystring {
//            request:
//             Request {
//               _events:
//                [Object: null prototype] {
//                  error: [Function: bound ],
//                  complete: [Function: bound ],
//                  pipe: [Function],
//                  data: [Function],
//                  end: [Function] },
//               _eventsCount: 5,
//               _maxListeners: undefined,
//               method: 'POST',
//               timeout: 60000,
//               callback: [Function],
//               readable: true,
//               writable: true,
//               explicitMethod: true,
//               _qs: [Circular],
//               _auth:
//                Auth {
//                  request: [Circular],
//                  hasAuth: false,
//                  sentAuth: false,
//                  bearerToken: null,
//                  user: null,
//                  pass: null },
//               _oauth: OAuth { request: [Circular], params: null },
//               _multipart:
//                Multipart {
//                  request: [Circular],
//                  boundary: '482c6eb7-dcb2-49ae-aff4-cd489bfaf0ef',
//                  chunked: false,
//                  body: null },
//               _redirect:
//                Redirect {
//                  request: [Circular],
//                  followRedirect: true,
//                  followRedirects: true,
//                  followAllRedirects: false,
//                  followOriginalHttpMethod: false,
//                  allowRedirect: [Function],
//                  maxRedirects: 10,
//                  redirects: [],
//                  redirectsFollowed: 0,
//                  removeRefererHeader: false },
//               _tunnel:
//                Tunnel {
//                  request: [Circular],
//                  proxyHeaderWhiteList:
//                   [ 'accept',
//                     'accept-charset',
//                     'accept-encoding',
//                     'accept-language',
//                     'accept-ranges',
//                     'cache-control',
//                     'content-encoding',
//                     'content-language',
//                     'content-location',
//                     'content-md5',
//                     'content-range',
//                     'content-type',
//                     'connection',
//                     'date',
//                     'expect',
//                     'max-forwards',
//                     'pragma',
//                     'referer',
//                     'te',
//                     'user-agent',
//                     'via' ],
//                  proxyHeaderExclusiveList: [] },
//               headers:
//                { accept: 'application/json',
//                  'content-type': 'application/json',
//                  'content-length': 74 },
//               setHeader: [Function],
//               hasHeader: [Function],
//               getHeader: [Function],
//               removeHeader: [Function],
//               localAddress: undefined,
//               pool: {},
//               dests: [],
//               __isRequestRequest: true,
//               _callback: [Function: bound ],
//               uri:
//                Url {
//                  protocol: 'https:',
//                  slashes: true,
//                  auth: null,
//                  host: 'mainnet.infura.io',
//                  port: 443,
//                  hostname: 'mainnet.infura.io',
//                  hash: null,
//                  search: null,
//                  query: null,
//                  pathname: '/v3/f565925a6c5143188b5589a37b28139b',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  href:
//                   'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b' },
//               proxy: null,
//               tunnel: true,
//               setHost: true,
//               originalCookieHeader: undefined,
//               _disableCookies: true,
//               _jar: undefined,
//               port: 443,
//               host: 'mainnet.infura.io',
//               path: '/v3/f565925a6c5143188b5589a37b28139b',
//               _json: true,
//               body:
//                '{"id":4,"jsonrpc":"2.0","method":"eth_subscribe","params":["newHeads",{}]}',
//               httpModule:
//                { Agent: [Function: Agent],
//                  globalAgent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  Server: [Function: Server],
//                  createServer: [Function: createServer],
//                  get: [Function: get],
//                  request: [Function: request] },
//               agentClass: [Function: Agent],
//               agent:
//                Agent {
//                  _events: [Object: null prototype] { free: [Function] },
//                  _eventsCount: 1,
//                  _maxListeners: undefined,
//                  defaultPort: 443,
//                  protocol: 'https:',
//                  options: { path: null },
//                  requests: {},
//                  sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                  freeSockets: {},
//                  keepAliveMsecs: 1000,
//                  keepAlive: false,
//                  maxSockets: Infinity,
//                  maxFreeSockets: 256,
//                  maxCachedSessions: 100,
//                  _sessionCache:
//                   { map:
//                      { 'mainnet.infura.io:443::::::::::::::::':
//                         <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                     list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//               _started: true,
//               href:
//                'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b',
//               req:
//                ClientRequest {
//                  _events:
//                   [Object: null prototype] {
//                     socket: [Function],
//                     response: [Function: bound ],
//                     error: [ [Function: bound ], [Function] ],
//                     drain: [Function],
//                     timeout: { [Function: bound onceWrapper] listener: [Function] },
//                     prefinish: [Function: requestOnPrefinish] },
//                  _eventsCount: 6,
//                  _maxListeners: undefined,
//                  output: [],
//                  outputEncodings: [],
//                  outputCallbacks: [],
//                  outputSize: 0,
//                  writable: true,
//                  _last: true,
//                  chunkedEncoding: false,
//                  shouldKeepAlive: false,
//                  useChunkedEncodingByDefault: true,
//                  sendDate: false,
//                  _removedConnection: false,
//                  _removedContLen: false,
//                  _removedTE: false,
//                  _contentLength: null,
//                  _hasBody: true,
//                  _trailer: '',
//                  finished: true,
//                  _headerSent: true,
//                  socket: [Circular],
//                  connection: [Circular],
//                  _header:
//                   'POST /v3/f565925a6c5143188b5589a37b28139b HTTP/1.1\r\nhost: mainnet.infura.io\r\naccept: application/json\r\ncontent-type: application/json\r\ncontent-length: 74\r\nConnection: close\r\n\r\n',
//                  _onPendingData: [Function: noopPendingOutput],
//                  agent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  socketPath: undefined,
//                  timeout: undefined,
//                  method: 'POST',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  _ended: true,
//                  res: [Circular],
//                  aborted: false,
//                  timeoutCb: [Function: emitRequestTimeout],
//                  upgradeOrConnect: false,
//                  parser: null,
//                  maxHeadersCount: null,
//                  [Symbol(isCorked)]: false,
//                  [Symbol(outHeadersKey)]:
//                   [Object: null prototype] {
//                     host: [ 'host', 'mainnet.infura.io' ],
//                     accept: [ 'accept', 'application/json' ],
//                     'content-type': [ 'content-type', 'application/json' ],
//                     'content-length': [ 'content-length', 74 ] } },
//               ntick: true,
//               timeoutTimer: null,
//               response: [Circular],
//               originalHost: 'mainnet.infura.io',
//               originalHostHeaderName: 'host',
//               responseContent: [Circular],
//               _destdata: true,
//               _ended: true,
//               _callbackCalled: true },
//            lib:
//             { formats:
//                { default: 'RFC3986',
//                  formatters:
//                   { RFC1738: [Function: RFC1738], RFC3986: [Function: RFC3986] },
//                  RFC1738: 'RFC1738',
//                  RFC3986: 'RFC3986' },
//               parse: [Function],
//               stringify: [Function] },
//            useQuerystring: undefined,
//            parseOptions: {},
//            stringifyOptions: {} },
//         _auth:
//          Auth {
//            request:
//             Request {
//               _events:
//                [Object: null prototype] {
//                  error: [Function: bound ],
//                  complete: [Function: bound ],
//                  pipe: [Function],
//                  data: [Function],
//                  end: [Function] },
//               _eventsCount: 5,
//               _maxListeners: undefined,
//               method: 'POST',
//               timeout: 60000,
//               callback: [Function],
//               readable: true,
//               writable: true,
//               explicitMethod: true,
//               _qs:
//                Querystring {
//                  request: [Circular],
//                  lib:
//                   { formats:
//                      { default: 'RFC3986',
//                        formatters:
//                         { RFC1738: [Function: RFC1738], RFC3986: [Function: RFC3986] },
//                        RFC1738: 'RFC1738',
//                        RFC3986: 'RFC3986' },
//                     parse: [Function],
//                     stringify: [Function] },
//                  useQuerystring: undefined,
//                  parseOptions: {},
//                  stringifyOptions: {} },
//               _auth: [Circular],
//               _oauth: OAuth { request: [Circular], params: null },
//               _multipart:
//                Multipart {
//                  request: [Circular],
//                  boundary: '482c6eb7-dcb2-49ae-aff4-cd489bfaf0ef',
//                  chunked: false,
//                  body: null },
//               _redirect:
//                Redirect {
//                  request: [Circular],
//                  followRedirect: true,
//                  followRedirects: true,
//                  followAllRedirects: false,
//                  followOriginalHttpMethod: false,
//                  allowRedirect: [Function],
//                  maxRedirects: 10,
//                  redirects: [],
//                  redirectsFollowed: 0,
//                  removeRefererHeader: false },
//               _tunnel:
//                Tunnel {
//                  request: [Circular],
//                  proxyHeaderWhiteList:
//                   [ 'accept',
//                     'accept-charset',
//                     'accept-encoding',
//                     'accept-language',
//                     'accept-ranges',
//                     'cache-control',
//                     'content-encoding',
//                     'content-language',
//                     'content-location',
//                     'content-md5',
//                     'content-range',
//                     'content-type',
//                     'connection',
//                     'date',
//                     'expect',
//                     'max-forwards',
//                     'pragma',
//                     'referer',
//                     'te',
//                     'user-agent',
//                     'via' ],
//                  proxyHeaderExclusiveList: [] },
//               headers:
//                { accept: 'application/json',
//                  'content-type': 'application/json',
//                  'content-length': 74 },
//               setHeader: [Function],
//               hasHeader: [Function],
//               getHeader: [Function],
//               removeHeader: [Function],
//               localAddress: undefined,
//               pool: {},
//               dests: [],
//               __isRequestRequest: true,
//               _callback: [Function: bound ],
//               uri:
//                Url {
//                  protocol: 'https:',
//                  slashes: true,
//                  auth: null,
//                  host: 'mainnet.infura.io',
//                  port: 443,
//                  hostname: 'mainnet.infura.io',
//                  hash: null,
//                  search: null,
//                  query: null,
//                  pathname: '/v3/f565925a6c5143188b5589a37b28139b',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  href:
//                   'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b' },
//               proxy: null,
//               tunnel: true,
//               setHost: true,
//               originalCookieHeader: undefined,
//               _disableCookies: true,
//               _jar: undefined,
//               port: 443,
//               host: 'mainnet.infura.io',
//               path: '/v3/f565925a6c5143188b5589a37b28139b',
//               _json: true,
//               body:
//                '{"id":4,"jsonrpc":"2.0","method":"eth_subscribe","params":["newHeads",{}]}',
//               httpModule:
//                { Agent: [Function: Agent],
//                  globalAgent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  Server: [Function: Server],
//                  createServer: [Function: createServer],
//                  get: [Function: get],
//                  request: [Function: request] },
//               agentClass: [Function: Agent],
//               agent:
//                Agent {
//                  _events: [Object: null prototype] { free: [Function] },
//                  _eventsCount: 1,
//                  _maxListeners: undefined,
//                  defaultPort: 443,
//                  protocol: 'https:',
//                  options: { path: null },
//                  requests: {},
//                  sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                  freeSockets: {},
//                  keepAliveMsecs: 1000,
//                  keepAlive: false,
//                  maxSockets: Infinity,
//                  maxFreeSockets: 256,
//                  maxCachedSessions: 100,
//                  _sessionCache:
//                   { map:
//                      { 'mainnet.infura.io:443::::::::::::::::':
//                         <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                     list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//               _started: true,
//               href:
//                'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b',
//               req:
//                ClientRequest {
//                  _events:
//                   [Object: null prototype] {
//                     socket: [Function],
//                     response: [Function: bound ],
//                     error: [ [Function: bound ], [Function] ],
//                     drain: [Function],
//                     timeout: { [Function: bound onceWrapper] listener: [Function] },
//                     prefinish: [Function: requestOnPrefinish] },
//                  _eventsCount: 6,
//                  _maxListeners: undefined,
//                  output: [],
//                  outputEncodings: [],
//                  outputCallbacks: [],
//                  outputSize: 0,
//                  writable: true,
//                  _last: true,
//                  chunkedEncoding: false,
//                  shouldKeepAlive: false,
//                  useChunkedEncodingByDefault: true,
//                  sendDate: false,
//                  _removedConnection: false,
//                  _removedContLen: false,
//                  _removedTE: false,
//                  _contentLength: null,
//                  _hasBody: true,
//                  _trailer: '',
//                  finished: true,
//                  _headerSent: true,
//                  socket: [Circular],
//                  connection: [Circular],
//                  _header:
//                   'POST /v3/f565925a6c5143188b5589a37b28139b HTTP/1.1\r\nhost: mainnet.infura.io\r\naccept: application/json\r\ncontent-type: application/json\r\ncontent-length: 74\r\nConnection: close\r\n\r\n',
//                  _onPendingData: [Function: noopPendingOutput],
//                  agent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  socketPath: undefined,
//                  timeout: undefined,
//                  method: 'POST',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  _ended: true,
//                  res: [Circular],
//                  aborted: false,
//                  timeoutCb: [Function: emitRequestTimeout],
//                  upgradeOrConnect: false,
//                  parser: null,
//                  maxHeadersCount: null,
//                  [Symbol(isCorked)]: false,
//                  [Symbol(outHeadersKey)]:
//                   [Object: null prototype] {
//                     host: [ 'host', 'mainnet.infura.io' ],
//                     accept: [ 'accept', 'application/json' ],
//                     'content-type': [ 'content-type', 'application/json' ],
//                     'content-length': [ 'content-length', 74 ] } },
//               ntick: true,
//               timeoutTimer: null,
//               response: [Circular],
//               originalHost: 'mainnet.infura.io',
//               originalHostHeaderName: 'host',
//               responseContent: [Circular],
//               _destdata: true,
//               _ended: true,
//               _callbackCalled: true },
//            hasAuth: false,
//            sentAuth: false,
//            bearerToken: null,
//            user: null,
//            pass: null },
//         _oauth:
//          OAuth {
//            request:
//             Request {
//               _events:
//                [Object: null prototype] {
//                  error: [Function: bound ],
//                  complete: [Function: bound ],
//                  pipe: [Function],
//                  data: [Function],
//                  end: [Function] },
//               _eventsCount: 5,
//               _maxListeners: undefined,
//               method: 'POST',
//               timeout: 60000,
//               callback: [Function],
//               readable: true,
//               writable: true,
//               explicitMethod: true,
//               _qs:
//                Querystring {
//                  request: [Circular],
//                  lib:
//                   { formats:
//                      { default: 'RFC3986',
//                        formatters:
//                         { RFC1738: [Function: RFC1738], RFC3986: [Function: RFC3986] },
//                        RFC1738: 'RFC1738',
//                        RFC3986: 'RFC3986' },
//                     parse: [Function],
//                     stringify: [Function] },
//                  useQuerystring: undefined,
//                  parseOptions: {},
//                  stringifyOptions: {} },
//               _auth:
//                Auth {
//                  request: [Circular],
//                  hasAuth: false,
//                  sentAuth: false,
//                  bearerToken: null,
//                  user: null,
//                  pass: null },
//               _oauth: [Circular],
//               _multipart:
//                Multipart {
//                  request: [Circular],
//                  boundary: '482c6eb7-dcb2-49ae-aff4-cd489bfaf0ef',
//                  chunked: false,
//                  body: null },
//               _redirect:
//                Redirect {
//                  request: [Circular],
//                  followRedirect: true,
//                  followRedirects: true,
//                  followAllRedirects: false,
//                  followOriginalHttpMethod: false,
//                  allowRedirect: [Function],
//                  maxRedirects: 10,
//                  redirects: [],
//                  redirectsFollowed: 0,
//                  removeRefererHeader: false },
//               _tunnel:
//                Tunnel {
//                  request: [Circular],
//                  proxyHeaderWhiteList:
//                   [ 'accept',
//                     'accept-charset',
//                     'accept-encoding',
//                     'accept-language',
//                     'accept-ranges',
//                     'cache-control',
//                     'content-encoding',
//                     'content-language',
//                     'content-location',
//                     'content-md5',
//                     'content-range',
//                     'content-type',
//                     'connection',
//                     'date',
//                     'expect',
//                     'max-forwards',
//                     'pragma',
//                     'referer',
//                     'te',
//                     'user-agent',
//                     'via' ],
//                  proxyHeaderExclusiveList: [] },
//               headers:
//                { accept: 'application/json',
//                  'content-type': 'application/json',
//                  'content-length': 74 },
//               setHeader: [Function],
//               hasHeader: [Function],
//               getHeader: [Function],
//               removeHeader: [Function],
//               localAddress: undefined,
//               pool: {},
//               dests: [],
//               __isRequestRequest: true,
//               _callback: [Function: bound ],
//               uri:
//                Url {
//                  protocol: 'https:',
//                  slashes: true,
//                  auth: null,
//                  host: 'mainnet.infura.io',
//                  port: 443,
//                  hostname: 'mainnet.infura.io',
//                  hash: null,
//                  search: null,
//                  query: null,
//                  pathname: '/v3/f565925a6c5143188b5589a37b28139b',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  href:
//                   'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b' },
//               proxy: null,
//               tunnel: true,
//               setHost: true,
//               originalCookieHeader: undefined,
//               _disableCookies: true,
//               _jar: undefined,
//               port: 443,
//               host: 'mainnet.infura.io',
//               path: '/v3/f565925a6c5143188b5589a37b28139b',
//               _json: true,
//               body:
//                '{"id":4,"jsonrpc":"2.0","method":"eth_subscribe","params":["newHeads",{}]}',
//               httpModule:
//                { Agent: [Function: Agent],
//                  globalAgent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  Server: [Function: Server],
//                  createServer: [Function: createServer],
//                  get: [Function: get],
//                  request: [Function: request] },
//               agentClass: [Function: Agent],
//               agent:
//                Agent {
//                  _events: [Object: null prototype] { free: [Function] },
//                  _eventsCount: 1,
//                  _maxListeners: undefined,
//                  defaultPort: 443,
//                  protocol: 'https:',
//                  options: { path: null },
//                  requests: {},
//                  sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                  freeSockets: {},
//                  keepAliveMsecs: 1000,
//                  keepAlive: false,
//                  maxSockets: Infinity,
//                  maxFreeSockets: 256,
//                  maxCachedSessions: 100,
//                  _sessionCache:
//                   { map:
//                      { 'mainnet.infura.io:443::::::::::::::::':
//                         <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                     list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//               _started: true,
//               href:
//                'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b',
//               req:
//                ClientRequest {
//                  _events:
//                   [Object: null prototype] {
//                     socket: [Function],
//                     response: [Function: bound ],
//                     error: [ [Function: bound ], [Function] ],
//                     drain: [Function],
//                     timeout: { [Function: bound onceWrapper] listener: [Function] },
//                     prefinish: [Function: requestOnPrefinish] },
//                  _eventsCount: 6,
//                  _maxListeners: undefined,
//                  output: [],
//                  outputEncodings: [],
//                  outputCallbacks: [],
//                  outputSize: 0,
//                  writable: true,
//                  _last: true,
//                  chunkedEncoding: false,
//                  shouldKeepAlive: false,
//                  useChunkedEncodingByDefault: true,
//                  sendDate: false,
//                  _removedConnection: false,
//                  _removedContLen: false,
//                  _removedTE: false,
//                  _contentLength: null,
//                  _hasBody: true,
//                  _trailer: '',
//                  finished: true,
//                  _headerSent: true,
//                  socket: [Circular],
//                  connection: [Circular],
//                  _header:
//                   'POST /v3/f565925a6c5143188b5589a37b28139b HTTP/1.1\r\nhost: mainnet.infura.io\r\naccept: application/json\r\ncontent-type: application/json\r\ncontent-length: 74\r\nConnection: close\r\n\r\n',
//                  _onPendingData: [Function: noopPendingOutput],
//                  agent:
//                   Agent {
//                     _events: [Object: null prototype] { free: [Function] },
//                     _eventsCount: 1,
//                     _maxListeners: undefined,
//                     defaultPort: 443,
//                     protocol: 'https:',
//                     options: { path: null },
//                     requests: {},
//                     sockets: { 'mainnet.infura.io:443::::::::::::::::': [ [Circular] ] },
//                     freeSockets: {},
//                     keepAliveMsecs: 1000,
//                     keepAlive: false,
//                     maxSockets: Infinity,
//                     maxFreeSockets: 256,
//                     maxCachedSessions: 100,
//                     _sessionCache:
//                      { map:
//                         { 'mainnet.infura.io:443::::::::::::::::':
//                            <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//                        list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//                  socketPath: undefined,
//                  timeout: undefined,
//                  method: 'POST',
//                  path: '/v3/f565925a6c5143188b5589a37b28139b',
//                  _ended: true,
//                  res: [Circular],
//                  aborted: false,
//                  timeoutCb: [Function: emitRequestTimeout],
//                  upgradeOrConnect: false,
//                  parser: null,
//                  maxHeadersCount: null,
//                  [Symbol(isCorked)]: false,
//                  [Symbol(outHeadersKey)]:
//                   [Object: null prototype] {
//                     host: [ 'host', 'mainnet.infura.io' ],
//                     accept: [ 'accept', 'application/json' ],
//                     'content-type': [ 'content-type', 'application/json' ],
//                     'content-length': [ 'content-length', 74 ] } },
//               ntick: true,
//               timeoutTimer: null,
//               response: [Circular],
//               originalHost: 'mainnet.infura.io',
//               originalHostHeaderName: 'host',
//               responseContent: [Circular],
//               _destdata: true,
//               _ended: true,
//               _callbackCalled: true },
//            params: null },
//         _multipart:
//          Multipart {
//            request:
//             Request {
//               _events:
//                [Object: null prototype] {
//                  error: [Function: bound ],
//                  complete: [Function: bound ],
//                  pipe: [Function],
//                  data: [Function],
//                  end: [Function] },
//               _eventsCount: 5,
//               _maxListeners: undefined,
//               method: 'POST',
//               timeout: 60000,
//               callback: [Function],
//               readable: true,
//               writable: true,
//               explicitMethod: true,
//               _qs:
//                Querystring {
//                  request: [Circular],
//                  lib:
//                   { formats:
//                      { default: 'RFC3986',
//                        formatters:
//                         { RFC1738: [Function: RFC1738], RFC3986: [Function: RFC3986] },
//                        RFC1738: 'RFC1738',
//                        RFC3986: 'RFC3986' },
//                     parse: [Function],
//                     stringify: [Function] },
//                  useQuerystring: undefined,
//                  parseOptions: {},
//                  stringifyOptions: {} },
//               _auth:
//                Auth {
//                  request: [Circular],
//                  hasAuth: false,
//                  sentAuth: false,
//                  bearerToken: null,
//                  user: null,
//                  pass: null },
//               _oauth: OAuth { request: [Circular], params: null },
//               _multipart: [Circular],
//               _redirect:
//                Redirect {
//                  request: [Circular],
//                  followRedirect: true,
//                  followRedirects: true,
//                  followAllRedirects: false,
//                  followOriginalHttpMethod: false,
//                  allowRedirect: [Function],
//                  maxRedirects: 10,
//                  redirects: [],
//                  redirectsFollowed: 0,
//                  removeRefererHeader: false },
//               _tunnel:
//                Tunnel {
//                  request: [Circular],
//                  proxyHeaderWhiteList:
//                   [ 'accept',
//                     'accept-charset',
//                     'accept-encoding',
//                     'accept-language',
//                     'accept-ranges',
//                     'cache-control',
//                     'content-encoding',
//                     'content-language',
//                     'content-location',
//                     'content-md5',
//                     'content-range',
//                     'content-type',
//                     'connection',
//                     'date',
//                     'expect',
//                     'max-forwards',
//                     'pragma',
//                     'referer',
//                     'te',
//                     'user-agent',
//                     'via' ],
//                  proxyHeaderExclusiveList: [] },
//               headers:
//                { accept: 'application/json',
//                  'content-type': 'application/json',
// ...
//                       _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//                       reading: true,
//                       onread: [Function: onStreamRead],
//                       onhandshakestart: [Function: noop],
//                       onhandshakedone: [Function: bound ],
//                       onocspresponse: [Function: onocspresponse],
//                       onerror: [Function: onerror],
//                       [Symbol(owner)]: [Circular] },
//                    _parent: null,
//                    _host: 'mainnet.infura.io',
//                    _readableState:
//                     ReadableState {
//                       objectMode: false,
//                       highWaterMark: 16384,
//                       buffer: BufferList { head: null, tail: null, length: 0 },
//                       length: 0,
//                       pipes: null,
//                       pipesCount: 0,
//                       flowing: true,
//                       ended: false,
//                       endEmitted: false,
//                       reading: true,
//                       sync: false,
//                       needReadable: true,
//                       emittedReadable: false,
//                       readableListening: false,
//                       resumeScheduled: false,
//                       emitClose: false,
//                       destroyed: false,
//                       defaultEncoding: 'utf8',
//                       awaitDrain: 0,
//                       readingMore: false,
//                       decoder: null,
//                       encoding: null },
//                    readable: true,
//                    _maxListeners: undefined,
//                    _writableState:
//                     WritableState {
//                       objectMode: false,
//                       highWaterMark: 16384,
//                       finalCalled: true,
//                       needDrain: false,
//                       ending: true,
//                       ended: true,
//                       finished: false,
//                       destroyed: false,
//                       decodeStrings: false,
//                       defaultEncoding: 'utf8',
//                       length: 0,
//                       writing: false,
//                       corked: 0,
//                       sync: false,
//                       bufferProcessing: false,
//                       onwrite: [Function: bound onwrite],
//                       writecb: null,
//                       writelen: 0,
//                       bufferedRequest: null,
//                       lastBufferedRequest: null,
//                       pendingcb: 1,
//                       prefinished: false,
//                       errorEmitted: false,
//                       emitClose: false,
//                       bufferedRequestCount: 0,
//                       corkedRequestsFree:
//                        { next:
//                           { next: null,
//                             entry: null,
//                             finish: [Function: bound onCorkedFinish] },
//                          entry: null,
//                          finish: [Function: bound onCorkedFinish] } },
//                    writable: false,
//                    allowHalfOpen: false,
//                    _sockname: null,
//                    _pendingData: null,
//                    _pendingEncoding: '',
//                    server: undefined,
//                    _server: null,
//                    ssl:
//                     TLSWrap {
//                       _parent:
//                        TCP {
//                          reading: [Getter/Setter],
//                          onread: null,
//                          onconnection: null,
//                          [Symbol(owner)]: [Circular] },
//                       _parentWrap: undefined,
//                       _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//                       reading: true,
//                       onread: [Function: onStreamRead],
//                       onhandshakestart: [Function: noop],
//                       onhandshakedone: [Function: bound ],
//                       onocspresponse: [Function: onocspresponse],
//                       onerror: [Function: onerror],
//                       [Symbol(owner)]: [Circular] },
//                    _requestCert: true,
//                    _rejectUnauthorized: true,
//                    parser: null,
//                    _httpMessage: [Circular],
//                    timeout: 60000,
//                    [Symbol(res)]:
//                     TLSWrap {
//                       _parent:
//                        TCP {
//                          reading: [Getter/Setter],
//                          onread: null,
//                          onconnection: null,
//                          [Symbol(owner)]: [Circular] },
//                       _parentWrap: undefined,
//                       _secureContext: SecureContext { context: SecureContext {}, singleUse: true },
//                       reading: true,
//                       onread: [Function: onStreamRead],
//                       onhandshakestart: [Function: noop],
//                       onhandshakedone: [Function: bound ],
//                       onocspresponse: [Function: onocspresponse],
//                       onerror: [Function: onerror],
//                       [Symbol(owner)]: [Circular] },
//                    [Symbol(asyncId)]: 130,
//                    [Symbol(lastWriteQueueSize)]: 0,
//                    [Symbol(timeout)]:
//                     Timeout {
//                       _idleTimeout: 60000,
//                       _idlePrev: [TimersList],
//                       _idleNext: [TimersList],
//                       _idleStart: 4851,
//                       _onTimeout: [Function: bound ],
//                       _timerArgs: undefined,
//                       _repeat: null,
//                       _destroyed: false,
//                       [Symbol(refed)]: false,
//                       [Symbol(asyncId)]: 140,
//                       [Symbol(triggerId)]: 138 },
//                    [Symbol(kBytesRead)]: 0,
//                    [Symbol(kBytesWritten)]: 0,
//                    [Symbol(connect-options)]:
//                     { rejectUnauthorized: true,
//                       ciphers:
//                        'ECDHE-RSA-AES128-GCM-SHA256:ECDHE-ECDSA-AES128-GCM-SHA256:ECDHE-RSA-AES256-GCM-SHA384:ECDHE-ECDSA-AES256-GCM-SHA384:DHE-RSA-AES128-GCM-SHA256:ECDHE-RSA-AES128-SHA256:DHE-RSA-AES128-SHA256:ECDHE-RSA-AES256-SHA384:DHE-RSA-AES256-SHA384:ECDHE-RSA-AES256-SHA256:DHE-RSA-AES256-SHA256:HIGH:!aNULL:!eNULL:!EXPORT:!DES:!RC4:!MD5:!PSK:!SRP:!CAMELLIA',
//                       checkServerIdentity: [Function: checkServerIdentity],
//                       minDHSize: 1024,
//                       servername: 'mainnet.infura.io',
//                       _defaultAgent: [Circular],
//                       _events:
//                        [Object: null prototype] {
//                          error: [Function: bound ],
//                          complete: [Function: bound ],
//                          pipe: [Function],
//                          data: [Function],
//                          end: [Function] },
//                       _eventsCount: 3,
//                       _maxListeners: undefined,
//                       method: 'POST',
//                       callback: [Function],
//                       readable: true,
//                       writable: true,
//                       explicitMethod: true,
//                       _qs:
//                        Querystring {
//                          request: [Circular],
//                          lib:
//                           { formats:
//                              { default: 'RFC3986',
//                                formatters:
//                                 { RFC1738: [Function: RFC1738], RFC3986: [Function: RFC3986] },
//                                RFC1738: 'RFC1738',
//                                RFC3986: 'RFC3986' },
//                             parse: [Function],
//                             stringify: [Function] },
//                          useQuerystring: undefined,
//                          parseOptions: {},
//                          stringifyOptions: {} },
//                       _auth:
//                        Auth {
//                          request: [Circular],
//                          hasAuth: false,
//                          sentAuth: false,
//                          bearerToken: null,
//                          user: null,
//                          pass: null },
//                       _oauth: OAuth { request: [Circular], params: null },
//                       _multipart:
//                        Multipart {
//                          request: [Circular],
//                          boundary: '482c6eb7-dcb2-49ae-aff4-cd489bfaf0ef',
//                          chunked: false,
//                          body: null },
//                       _redirect:
//                        Redirect {
//                          request: [Circular],
//                          followRedirect: true,
//                          followRedirects: true,
//                          followAllRedirects: false,
//                          followOriginalHttpMethod: false,
//                          allowRedirect: [Function],
//                          maxRedirects: 10,
//                          redirects: [],
//                          redirectsFollowed: 0,
//                          removeRefererHeader: false },
//                       _tunnel:
//                        Tunnel {
//                          request: [Circular],
//                          proxyHeaderWhiteList:
//                           [ 'accept',
//                             'accept-charset',
//                             'accept-encoding',
//                             'accept-language',
//                             'accept-ranges',
//                             'cache-control',
//                             'content-encoding',
//                             'content-language',
//                             'content-location',
//                             'content-md5',
//                             'content-range',
//                             'content-type',
//                             'connection',
//                             'date',
//                             'expect',
//                             'max-forwards',
//                             'pragma',
//                             'referer',
//                             'te',
//                             'user-agent',
//                             'via' ],
//                          proxyHeaderExclusiveList: [] },
//                       headers:
//                        { accept: 'application/json',
//                          'content-type': 'application/json',
//                          'content-length': 74 },
//                       setHeader: [Function],
//                       hasHeader: [Function],
//                       getHeader: [Function],
//                       removeHeader: [Function],
//                       localAddress: undefined,
//                       pool: {},
//                       dests: [],
//                       __isRequestRequest: true,
//                       _callback: [Function: bound ],
//                       uri:
//                        Url {
//                          protocol: 'https:',
//                          slashes: true,
//                          auth: null,
//                          host: 'mainnet.infura.io',
//                          port: 443,
//                          hostname: 'mainnet.infura.io',
//                          hash: null,
//                          search: null,
//                          query: null,
//                          pathname: '/v3/f565925a6c5143188b5589a37b28139b',
//                          path: '/v3/f565925a6c5143188b5589a37b28139b',
//                          href:
//                           'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b' },
//                       proxy: null,
//                       tunnel: true,
//                       setHost: true,
//                       originalCookieHeader: undefined,
//                       _disableCookies: true,
//                       _jar: undefined,
//                       port: 443,
//                       host: 'mainnet.infura.io',
//                       path: null,
//                       _json: true,
//                       body:
//                        '{"id":4,"jsonrpc":"2.0","method":"eth_subscribe","params":["newHeads",{}]}',
//                       httpModule:
//                        { Agent: [Function: Agent],
//                          globalAgent: [Circular],
//                          Server: [Function: Server],
//                          createServer: [Function: createServer],
//                          get: [Function: get],
//                          request: [Function: request] },
//                       agentClass: [Function: Agent],
//                       agent: [Circular],
//                       _started: true,
//                       href:
//                        'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b',
//                       _agentKey: 'mainnet.infura.io:443::::::::::::::::',
//                       encoding: null,
//                       session:
//                        <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes>,
//                       singleUse: true } } ] },
//            freeSockets: {},
//            keepAliveMsecs: 1000,
//            keepAlive: false,
//            maxSockets: Infinity,
//            maxFreeSockets: 256,
//            maxCachedSessions: 100,
//            _sessionCache:
//             { map:
//                { 'mainnet.infura.io:443::::::::::::::::':
//                   <Buffer 30 82 06 cf 02 01 01 02 02 03 03 04 02 c0 2f 04 20 8f f6 05 f4 14 68 55 0e 35 41 0f 73 e8 93 3a a7 a6 b2 e0 c6 75 31 71 80 a2 4c ad bd 4c b3 9c d6 04 ... 1697 more bytes> },
//               list: [ 'mainnet.infura.io:443::::::::::::::::' ] } },
//         socketPath: undefined,
//         timeout: undefined,
//         method: 'POST',
//         path: '/v3/f565925a6c5143188b5589a37b28139b',
//         _ended: true,
//         res: [Circular],
//         aborted: false,
//         timeoutCb: [Function: emitRequestTimeout],
//         upgradeOrConnect: false,
//         parser: null,
//         maxHeadersCount: null,
//         [Symbol(isCorked)]: false,
//         [Symbol(outHeadersKey)]:
//          [Object: null prototype] {
//            host: [ 'host', 'mainnet.infura.io' ],
//            accept: [ 'accept', 'application/json' ],
//            'content-type': [ 'content-type', 'application/json' ],
//            'content-length': [ 'content-length', 74 ] } },
//      ntick: true,
//      timeoutTimer: null,
//      response: [Circular],
//      originalHost: 'mainnet.infura.io',
//      originalHostHeaderName: 'host',
//      responseContent: [Circular],
//      _destdata: true,
//      _ended: true,
//      _callbackCalled: true },
//   toJSON: [Function: responseToJSON],
//   caseless:
//    Caseless {
//      dict:
//       { date: 'Sat, 08 Dec 2018 15:18:13 GMT',
//         'content-type': 'application/json',
//         'content-length': '117',
//         connection: 'close',
//         vary: 'Origin' } },
//   body:
//    { jsonrpc: '2.0',
//      id: 4,
//      error:
//       { code: -32601,
//         message: 'The method eth_subscribe does not exist/is not available' } } }
// { Error: Unexpected status code.
//     at HttpTransport.<anonymous> (/Users/mettinger/node_modules/ethrpc/src/transport/http-transport.js:96:15)
//     at Request.self.callback (/Users/mettinger/node_modules/ethrpc/node_modules/request/request.js:186:22)
//     at Request.emit (events.js:182:13)
//     at Request.<anonymous> (/Users/mettinger/node_modules/ethrpc/node_modules/request/request.js:1163:10)
//     at Request.emit (events.js:182:13)
//     at IncomingMessage.<anonymous> (/Users/mettinger/node_modules/ethrpc/node_modules/request/request.js:1085:12)
//     at Object.onceWrapper (events.js:273:13)
//     at IncomingMessage.emit (events.js:187:15)
//     at endReadableNT (_stream_readable.js:1094:12)
//     at process.internalTickCallback (internal/process/next_tick.js:72:19)
//   code: 400,
//   address:
//    'https://mainnet.infura.io/v3/f565925a6c5143188b5589a37b28139b',
//   data:
//    { id: 4,
//      jsonrpc: '2.0',
//      method: 'eth_subscribe',
//      params: [ 'newHeads', {} ] } }

// %%
myConnectionInfo
// Out:
// { augurNode: 'ws://18.208.37.82:9001',
//   ethereumNode:
//    { contracts:
//       { Controller: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7',
//         Universe: '0xe991247b78f937d7b69cfc00f1a487a293557677',
//         Augur: '0x75228dce4d82566d93068a8d5d49435216551599',
//         OrdersFinder: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df',
//         LegacyReputationToken: '0xe94327d07fc17907b4db788e5adf2ed424addff6',
//         CancelOrder: '0x3448209268e97652bb67ea12777d4dfba81e3aaf',
//         Cash: '0xd5524179cb7ae012f5b642c1d6d700bbaa76b96b',
//         ClaimTradingProceeds: '0x4334477348222a986fc88a05410aa6b07507872a',
//         CompleteSets: '0xa6bff4f91016c2b4aac140b2d8d7317b36afe5ab',
//         CreateOrder: '0x7f27b0598949dbf9e539bbd217f15bf3f5e97999',
//         FillOrder: '0x39c230f89981274177e79708c921582bd4bd0303',
//         Order: '0x75d789ef6344579fbe75a4d2d9217ec23b005f8f',
//         Orders: '0xd7a14019aeeba25e676a1b596bb19b6f37db74d2',
//         OrdersFetcher: '0xa97a3e2ac932bc7a9c65393ee2c0f9d2f7b2e692',
//         ShareToken: '0x2a21d90745dfed999aa0b6e08d648855c5f14663',
//         Trade: '0x24e2b1d415e6e0d04042eaa45dc2a08fc33ca6cd',
//         TradingEscapeHatch: '0x10b5589fc6922f5c27061ac79ad9a4af35e15806' },
//      abi:
//       { functions:
//          { Augur:
//             { logDisputeCrowdsourcerRedeemed:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerRedeemed',
//                  inputs:
//                   [ '_universe',
//                     '_reporter',
//                     '_market',
//                     '_amountRedeemed',
//                     '_repReceived',
//                     '_reportingFeesReceived',
//                     '_payoutNumerators' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256[]' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketCreated:
//                { constant: false,
//                  name: 'logMarketCreated',
//                  inputs:
//                   [ '_topic',
//                     '_description',
//                     '_extraInfo',
//                     '_universe',
//                     '_market',
//                     '_marketCreator',
//                     '_minPrice',
//                     '_maxPrice',
//                     '_marketType' ],
//                  signature:
//                   [ 'bytes32',
//                     'string',
//                     'string',
//                     'address',
//                     'address',
//                     'address',
//                     'int256',
//                     'int256',
//                     'uint8' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logOrderCreated:
//                { constant: false,
//                  name: 'logOrderCreated',
//                  inputs:
//                   [ '_orderType',
//                     '_amount',
//                     '_price',
//                     '_creator',
//                     '_moneyEscrowed',
//                     '_sharesEscrowed',
//                     '_tradeGroupId',
//                     '_orderId',
//                     '_universe',
//                     '_shareToken' ],
//                  signature:
//                   [ 'uint8',
//                     'uint256',
//                     'uint256',
//                     'address',
//                     'uint256',
//                     'uint256',
//                     'bytes32',
//                     'bytes32',
//                     'address',
//                     'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logDisputeCrowdsourcerTokensBurned:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerTokensBurned',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logReportingParticipantDisavowed:
//                { constant: false,
//                  name: 'logReportingParticipantDisavowed',
//                  inputs: [ '_universe', '_market' ],
//                  signature: [ 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketMigrated:
//                { constant: false,
//                  name: 'logMarketMigrated',
//                  inputs: [ '_market', '_originalUniverse' ],
//                  signature: [ 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketTransferred:
//                { constant: false,
//                  name: 'logMarketTransferred',
//                  inputs: [ '_universe', '_from', '_to' ],
//                  signature: [ 'address', 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeTokenMinted:
//                { constant: false,
//                  name: 'logFeeTokenMinted',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketFinalized:
//                { constant: false,
//                  name: 'logMarketFinalized',
//                  inputs: [ '_universe' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               getController:
//                { constant: true,
//                  name: 'getController',
//                  returns: 'address',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketMailboxTransferred:
//                { constant: false,
//                  name: 'logMarketMailboxTransferred',
//                  inputs: [ '_universe', '_market', '_from', '_to' ],
//                  signature: [ 'address', 'address', 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeTokenTransferred:
//                { constant: false,
//                  name: 'logFeeTokenTransferred',
//                  inputs: [ '_universe', '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeWindowRedeemed:
//                { constant: false,
//                  name: 'logFeeWindowRedeemed',
//                  inputs:
//                   [ '_universe',
//                     '_reporter',
//                     '_amountRedeemed',
//                     '_reportingFeesReceived' ],
//                  signature: [ 'address', 'address', 'uint256', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logReputationTokenBurned:
//                { constant: false,
//                  name: 'logReputationTokenBurned',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logUniverseForked:
//                { constant: false,
//                  name: 'logUniverseForked',
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logDisputeCrowdsourcerCompleted:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerCompleted',
//                  inputs: [ '_universe', '_market', '_disputeCrowdsourcer' ],
//                  signature: [ 'address', 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logDisputeCrowdsourcerTokensTransferred:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerTokensTransferred',
//                  inputs: [ '_universe', '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logDisputeCrowdsourcerContribution:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerContribution',
//                  inputs:
//                   [ '_universe',
//                     '_reporter',
//                     '_market',
//                     '_disputeCrowdsourcer',
//                     '_amountStaked' ],
//                  signature: [ 'address', 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeWindowBurned:
//                { constant: false,
//                  name: 'logFeeWindowBurned',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logTradingProceedsClaimed:
//                { constant: false,
//                  name: 'logTradingProceedsClaimed',
//                  inputs:
//                   [ '_universe',
//                     '_shareToken',
//                     '_sender',
//                     '_market',
//                     '_numShares',
//                     '_numPayoutTokens',
//                     '_finalTokenBalance' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'address',
//                     'uint256',
//                     'uint256',
//                     'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeWindowMinted:
//                { constant: false,
//                  name: 'logFeeWindowMinted',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logOrderCanceled:
//                { constant: false,
//                  name: 'logOrderCanceled',
//                  inputs:
//                   [ '_universe',
//                     '_shareToken',
//                     '_sender',
//                     '_orderId',
//                     '_orderType',
//                     '_tokenRefund',
//                     '_sharesRefund' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'bytes32',
//                     'uint8',
//                     'uint256',
//                     'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logInitialReportSubmitted:
//                { constant: false,
//                  name: 'logInitialReportSubmitted',
//                  inputs:
//                   [ '_universe',
//                     '_reporter',
//                     '_market',
//                     '_amountStaked',
//                     '_isDesignatedReporter',
//                     '_payoutNumerators',
//                     '_invalid' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'uint256',
//                     'bool',
//                     'uint256[]',
//                     'bool' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeWindowTransferred:
//                { constant: false,
//                  name: 'logFeeWindowTransferred',
//                  inputs: [ '_universe', '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logReputationTokenMinted:
//                { constant: false,
//                  name: 'logReputationTokenMinted',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               disputeCrowdsourcerCreated:
//                { constant: false,
//                  name: 'disputeCrowdsourcerCreated',
//                  inputs:
//                   [ '_universe',
//                     '_market',
//                     '_disputeCrowdsourcer',
//                     '_payoutNumerators',
//                     '_size',
//                     '_invalid' ],
//                  signature:
//                   [ 'address', 'address', 'address', 'uint256[]', 'uint256', 'bool' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logOrderFilled:
//                { constant: false,
//                  name: 'logOrderFilled',
//                  inputs:
//                   [ '_universe',
//                     '_shareToken',
//                     '_filler',
//                     '_orderId',
//                     '_numCreatorShares',
//                     '_numCreatorTokens',
//                     '_numFillerShares',
//                     '_numFillerTokens',
//                     '_marketCreatorFees',
//                     '_reporterFees',
//                     '_amountFilled',
//                     '_tradeGroupId' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'bytes32',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'bytes32' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logShareTokensTransferred:
//                { constant: false,
//                  name: 'logShareTokensTransferred',
//                  inputs: [ '_universe', '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               createChildUniverse:
//                { constant: false,
//                  name: 'createChildUniverse',
//                  inputs:
//                   [ '_parentPayoutDistributionHash',
//                     '_parentPayoutNumerators',
//                     '_parentInvalid' ],
//                  signature: [ 'bytes32', 'uint256[]', 'bool' ],
//                  returns: 'address',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               isKnownUniverse:
//                { constant: true,
//                  name: 'isKnownUniverse',
//                  inputs: [ '_universe' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeWindowCreated:
//                { constant: false,
//                  name: 'logFeeWindowCreated',
//                  inputs: [ '_feeWindow', '_id' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               createGenesisUniverse:
//                { constant: false,
//                  name: 'createGenesisUniverse',
//                  returns: 'address',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logFeeTokenBurned:
//                { constant: false,
//                  name: 'logFeeTokenBurned',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logShareTokenBurned:
//                { constant: false,
//                  name: 'logShareTokenBurned',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logShareTokenMinted:
//                { constant: false,
//                  name: 'logShareTokenMinted',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logEscapeHatchChanged:
//                { constant: false,
//                  name: 'logEscapeHatchChanged',
//                  inputs: [ '_isOn' ],
//                  signature: [ 'bool' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logDisputeCrowdsourcerTokensMinted:
//                { constant: false,
//                  name: 'logDisputeCrowdsourcerTokensMinted',
//                  inputs: [ '_universe', '_target', '_amount' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               isKnownCrowdsourcer:
//                { constant: true,
//                  name: 'isKnownCrowdsourcer',
//                  inputs: [ '_crowdsourcer' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logCompleteSetsPurchased:
//                { constant: false,
//                  name: 'logCompleteSetsPurchased',
//                  inputs: [ '_universe', '_market', '_account', '_numCompleteSets' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logMarketParticipantsDisavowed:
//                { constant: false,
//                  name: 'logMarketParticipantsDisavowed',
//                  inputs: [ '_universe' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logTimestampSet:
//                { constant: false,
//                  name: 'logTimestampSet',
//                  inputs: [ '_newTimestamp' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logInitialReporterTransferred:
//                { constant: false,
//                  name: 'logInitialReporterTransferred',
//                  inputs: [ '_universe', '_market', '_from', '_to' ],
//                  signature: [ 'address', 'address', 'address', 'address' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logInitialReporterRedeemed:
//                { constant: false,
//                  name: 'logInitialReporterRedeemed',
//                  inputs:
//                   [ '_universe',
//                     '_reporter',
//                     '_market',
//                     '_amountRedeemed',
//                     '_repReceived',
//                     '_reportingFeesReceived',
//                     '_payoutNumerators' ],
//                  signature:
//                   [ 'address',
//                     'address',
//                     'address',
//                     'uint256',
//                     'uint256',
//                     'uint256',
//                     'uint256[]' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               trustedTransfer:
//                { constant: false,
//                  name: 'trustedTransfer',
//                  inputs: [ '_token', '_from', '_to', '_amount' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logReputationTokensTransferred:
//                { constant: false,
//                  name: 'logReputationTokensTransferred',
//                  inputs: [ '_universe', '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               logCompleteSetsSold:
//                { constant: false,
//                  name: 'logCompleteSetsSold',
//                  inputs: [ '_universe', '_market', '_account', '_numCompleteSets' ],
//                  signature: [ 'address', 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0x75228dce4d82566d93068a8d5d49435216551599' } },
//            Controlled:
//             { getController:
//                { constant: true,
//                  name: 'getController',
//                  returns: 'address',
//                  to: undefined },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined } },
//            Controller:
//             { getContractDetails:
//                { constant: true,
//                  name: 'getContractDetails',
//                  inputs: [ '_key' ],
//                  signature: [ 'bytes32' ],
//                  returns: 'address',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               getTimestamp:
//                { constant: true,
//                  name: 'getTimestamp',
//                  returns: 'uint256',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               stopInEmergency:
//                { constant: true,
//                  name: 'stopInEmergency',
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               registerContract:
//                { constant: false,
//                  name: 'registerContract',
//                  inputs: [ '_key', '_address', '_commitHash', '_bytecodeHash' ],
//                  signature: [ 'bytes32', 'address', 'bytes20', 'bytes32' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               onlyInEmergency:
//                { constant: true,
//                  name: 'onlyInEmergency',
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               assertIsWhitelisted:
//                { constant: true,
//                  name: 'assertIsWhitelisted',
//                  inputs: [ '_target' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               getAugur:
//                { constant: true,
//                  name: 'getAugur',
//                  returns: 'address',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               emergencyStop:
//                { constant: false,
//                  name: 'emergencyStop',
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               stopped:
//                { constant: true,
//                  name: 'stopped',
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               registry:
//                { constant: true,
//                  name: 'registry',
//                  inputs: [ '' ],
//                  signature: [ 'bytes32' ],
//                  returns: 'bytes32',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               removeFromWhitelist:
//                { constant: false,
//                  name: 'removeFromWhitelist',
//                  inputs: [ '_target' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               owner:
//                { constant: true,
//                  name: 'owner',
//                  returns: 'address',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               whitelist:
//                { constant: true,
//                  name: 'whitelist',
//                  inputs: [ '' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               addToWhitelist:
//                { constant: false,
//                  name: 'addToWhitelist',
//                  inputs: [ '_target' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               transferOwnership:
//                { constant: false,
//                  name: 'transferOwnership',
//                  inputs: [ '_newOwner' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' },
//               lookup:
//                { constant: true,
//                  name: 'lookup',
//                  inputs: [ '_key' ],
//                  signature: [ 'bytes32' ],
//                  returns: 'address',
//                  to: '0xb3337164e91b9f05c87c7662c7ac684e8e0ff3e7' } },
//            LegacyReputationToken:
//             { name:
//                { constant: true,
//                  name: 'name',
//                  returns: 'string',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               approve:
//                { constant: false,
//                  name: 'approve',
//                  inputs: [ '_spender', '_value' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               totalSupply:
//                { constant: true,
//                  name: 'totalSupply',
//                  returns: 'uint256',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               transferFrom:
//                { constant: false,
//                  name: 'transferFrom',
//                  inputs: [ '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               decimals:
//                { constant: true,
//                  name: 'decimals',
//                  returns: 'uint256',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               unpause:
//                { constant: false,
//                  name: 'unpause',
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               faucet:
//                { constant: false,
//                  name: 'faucet',
//                  inputs: [ '_amount' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               paused:
//                { constant: true,
//                  name: 'paused',
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               ETERNAL_APPROVAL_VALUE:
//                { constant: true,
//                  name: 'ETERNAL_APPROVAL_VALUE',
//                  returns: 'uint256',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               decreaseApproval:
//                { constant: false,
//                  name: 'decreaseApproval',
//                  inputs: [ '_spender', '_subtractedValue' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               balanceOf:
//                { constant: true,
//                  name: 'balanceOf',
//                  inputs: [ '_owner' ],
//                  signature: [ 'address' ],
//                  returns: 'uint256',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               pause:
//                { constant: false,
//                  name: 'pause',
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               getOwner:
//                { constant: true,
//                  name: 'getOwner',
//                  returns: 'address',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               symbol:
//                { constant: true,
//                  name: 'symbol',
//                  returns: 'string',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               transfer:
//                { constant: false,
//                  name: 'transfer',
//                  inputs: [ '_to', '_value' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               increaseApproval:
//                { constant: false,
//                  name: 'increaseApproval',
//                  inputs: [ '_spender', '_addedValue' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               allowance:
//                { constant: true,
//                  name: 'allowance',
//                  inputs: [ '_owner', '_spender' ],
//                  signature: [ 'address', 'address' ],
//                  returns: 'uint256',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               transferOwnership:
//                { constant: false,
//                  name: 'transferOwnership',
//                  inputs: [ '_newOwner' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: '0xe94327d07fc17907b4db788e5adf2ed424addff6' } },
//            TestNetReputationToken:
//             { name:
//                { constant: true, name: 'name', returns: 'string', to: undefined },
//               approve:
//                { constant: false,
//                  name: 'approve',
//                  inputs: [ '_spender', '_value' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               totalSupply:
//                { constant: true,
//                  name: 'totalSupply',
//                  returns: 'uint256',
//                  to: undefined },
//               getTotalTheoreticalSupply:
//                { constant: true,
//                  name: 'getTotalTheoreticalSupply',
//                  returns: 'uint256',
//                  to: undefined },
//               transferFrom:
//                { constant: false,
//                  name: 'transferFrom',
//                  inputs: [ '_from', '_to', '_value' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               getController:
//                { constant: true,
//                  name: 'getController',
//                  returns: 'address',
//                  to: undefined },
//               decimals:
//                { constant: true,
//                  name: 'decimals',
//                  returns: 'uint8',
//                  to: undefined },
//               migrateOutByPayout:
//                { constant: false,
//                  name: 'migrateOutByPayout',
//                  inputs: [ '_payoutNumerators', '_invalid', '_attotokens' ],
//                  signature: [ 'uint256[]', 'bool', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               faucet:
//                { constant: false,
//                  name: 'faucet',
//                  inputs: [ '_amount' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               ETERNAL_APPROVAL_VALUE:
//                { constant: true,
//                  name: 'ETERNAL_APPROVAL_VALUE',
//                  returns: 'uint256',
//                  to: undefined },
//               decreaseApproval:
//                { constant: false,
//                  name: 'decreaseApproval',
//                  inputs: [ '_spender', '_subtractedValue' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               migrateOut:
//                { constant: false,
//                  name: 'migrateOut',
//                  inputs: [ '_destination', '_attotokens' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               balanceOf:
//                { constant: true,
//                  name: 'balanceOf',
//                  inputs: [ '_owner' ],
//                  signature: [ 'address' ],
//                  returns: 'uint256',
//                  to: undefined },
//               getLegacyRepToken:
//                { constant: true,
//                  name: 'getLegacyRepToken',
//                  returns: 'address',
//                  to: undefined },
//               getIsMigratingFromLegacy:
//                { constant: true,
//                  name: 'getIsMigratingFromLegacy',
//                  returns: 'bool',
//                  to: undefined },
//               migrateBalancesFromLegacyRep:
//                { constant: false,
//                  name: 'migrateBalancesFromLegacyRep',
//                  inputs: [ '_holders' ],
//                  signature: [ 'address[]' ],
//                  returns: 'bool',
//                  to: undefined },
//               getUniverse:
//                { constant: true,
//                  name: 'getUniverse',
//                  returns: 'address',
//                  to: undefined },
//               trustedFeeWindowTransfer:
//                { constant: false,
//                  name: 'trustedFeeWindowTransfer',
//                  inputs: [ '_source', '_destination', '_attotokens' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               getTotalMigrated:
//                { constant: true,
//                  name: 'getTotalMigrated',
//                  returns: 'uint256',
//                  to: undefined },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               symbol:
//                { constant: true,
//                  name: 'symbol',
//                  returns: 'string',
//                  to: undefined },
//               migrateIn:
//                { constant: false,
//                  name: 'migrateIn',
//                  inputs: [ '_reporter', '_attotokens' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               updateParentTotalTheoreticalSupply:
//                { constant: false,
//                  name: 'updateParentTotalTheoreticalSupply',
//                  returns: 'bool',
//                  to: undefined },
//               transfer:
//                { constant: false,
//                  name: 'transfer',
//                  inputs: [ '_to', '_value' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               trustedReportingParticipantTransfer:
//                { constant: false,
//                  name: 'trustedReportingParticipantTransfer',
//                  inputs: [ '_source', '_destination', '_attotokens' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               controllerLookupName:
//                { constant: true,
//                  name: 'controllerLookupName',
//                  returns: 'bytes32',
//                  to: undefined },
//               initialize:
//                { constant: false,
//                  name: 'initialize',
//                  inputs: [ '_universe' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               increaseApproval:
//                { constant: false,
//                  name: 'increaseApproval',
//                  inputs: [ '_spender', '_addedValue' ],
//                  signature: [ 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               updateSiblingMigrationTotal:
//                { constant: false,
//                  name: 'updateSiblingMigrationTotal',
//                  inputs: [ '_token' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               mintForReportingParticipant:
//                { constant: false,
//                  name: 'mintForReportingParticipant',
//                  inputs: [ '_amountMigrated' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               getTypeName:
//                { constant: true,
//                  name: 'getTypeName',
//                  returns: 'bytes32',
//                  to: undefined },
//               allowance:
//                { constant: true,
//                  name: 'allowance',
//                  inputs: [ '_owner', '_spender' ],
//                  signature: [ 'address', 'address' ],
//                  returns: 'uint256',
//                  to: undefined },
//               migrateAllowancesFromLegacyRep:
//                { constant: false,
//                  name: 'migrateAllowancesFromLegacyRep',
//                  inputs: [ '_owners', '_spenders' ],
//                  signature: [ 'address[]', 'address[]' ],
//                  returns: 'bool',
//                  to: undefined },
//               getTargetSupply:
//                { constant: true,
//                  name: 'getTargetSupply',
//                  returns: 'uint256',
//                  to: undefined },
//               getInitialized:
//                { constant: true,
//                  name: 'getInitialized',
//                  returns: 'bool',
//                  to: undefined },
//               trustedMarketTransfer:
//                { constant: false,
//                  name: 'trustedMarketTransfer',
//                  inputs: [ '_source', '_destination', '_attotokens' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               trustedUniverseTransfer:
//                { constant: false,
//                  name: 'trustedUniverseTransfer',
//                  inputs: [ '_source', '_destination', '_attotokens' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'bool',
//                  to: undefined } },
//            Time:
//             { getTimestamp:
//                { constant: true,
//                  name: 'getTimestamp',
//                  returns: 'uint256',
//                  to: undefined },
//               getController:
//                { constant: true,
//                  name: 'getController',
//                  returns: 'address',
//                  to: undefined },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               getTypeName:
//                { constant: true,
//                  name: 'getTypeName',
//                  returns: 'bytes32',
//                  to: undefined } },
//            TimeControlled:
//             { getTimestamp:
//                { constant: true,
//                  name: 'getTimestamp',
//                  returns: 'uint256',
//                  to: undefined },
//               getController:
//                { constant: true,
//                  name: 'getController',
//                  returns: 'address',
//                  to: undefined },
//               getOwner:
//                { constant: true,
//                  name: 'getOwner',
//                  returns: 'address',
//                  to: undefined },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               setTimestamp:
//                { constant: false,
//                  name: 'setTimestamp',
//                  inputs: [ '_timestamp' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               incrementTimestamp:
//                { constant: false,
//                  name: 'incrementTimestamp',
//                  inputs: [ '_amount' ],
//                  signature: [ 'uint256' ],
//                  returns: 'bool',
//                  to: undefined },
//               getTypeName:
//                { constant: true,
//                  name: 'getTypeName',
//                  returns: 'bytes32',
//                  to: undefined },
//               transferOwnership:
//                { constant: false,
//                  name: 'transferOwnership',
//                  inputs: [ '_newOwner' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined } },
//            EscapeHatchController:
//             { emergencyStop:
//                { constant: false,
//                  name: 'emergencyStop',
//                  returns: 'bool',
//                  to: undefined },
//               getOwner:
//                { constant: true,
//                  name: 'getOwner',
//                  returns: 'address',
//                  to: undefined },
//               setController:
//                { constant: false,
//                  name: 'setController',
//                  inputs: [ '_controller' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               transferOwnership:
//                { constant: false,
//                  name: 'transferOwnership',
//                  inputs: [ '_newOwner' ],
//                  signature: [ 'address' ],
//                  returns: 'bool',
//                  to: undefined },
//               controller:
//                { constant: true,
//                  name: 'controller',
//                  returns: 'address',
//                  to: undefined } },
//            OrdersFinder:
//             { getExistingOrders5:
//                { constant: true,
//                  name: 'getExistingOrders5',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[5]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders20:
//                { constant: true,
//                  name: 'getExistingOrders20',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[20]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               orders:
//                { constant: true,
//                  name: 'orders',
//                  returns: 'address',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders1000:
//                { constant: true,
//                  name: 'getExistingOrders1000',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[1000]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders50:
//                { constant: true,
//                  name: 'getExistingOrders50',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[50]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders500:
//                { constant: true,
//                  name: 'getExistingOrders500',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[500]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders200:
//                { constant: true,
//                  name: 'getExistingOrders200',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[200]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders100:
//                { constant: true,
//                  name: 'getExistingOrders100',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[100]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' },
//               getExistingOrders10:
//                { constant: true,
//                  name: 'getExistingOrders10',
//                  inputs: [ '_type', '_market', '_outcome' ],
//                  signature: [ 'uint8', 'address', 'uint256' ],
//                  returns: 'bytes32[10]',
//                  to: '0x01f2aba090b5fa26a64ea9e5afd32f6aab6ba3df' } },
//            DisputeCrowdsourcerFactory:
//             { createDisputeCrowdsourcer:
//                { constant: false,
//                  name: 'createDisputeCrowdsourcer',
//                  inputs:
//                   [ '_controller',
//                     '_market',
//                     '_size',
//                     '_payoutDistributionHash',
//                     '_payoutNumerators',
//                     '_invalid' ],
//                  signature:
//                   [ 'address', 'address', 'uint256', 'bytes32', 'uint256[]', 'bool' ],
//                  returns: 'address',
//                  to: undefined } },
//            FeeTokenFactory:
//             { createFeeToken:
//                { constant: false,
//                  name: 'createFeeToken',
//                  inputs: [ '_controller', '_feeWindow' ],
//                  signature: [ 'address', 'address' ],
//                  returns: 'address',
//                  to: undefined } },
//            FeeWindowFactory:
//             { createFeeWindow:
//                { constant: false,
//                  name: 'createFeeWindow',
//                  inputs: [ '_controller', '_universe', '_feeWindowId' ],
//                  signature: [ 'address', 'address', 'uint256' ],
//                  returns: 'address',
//                  to: undefined } },
//            InitialReporterFactory:
//             { createInitialReporter:
//                { constant: false,
//                  name: 'createInitialReporter',
//                  inputs: [ '_controller', '_market', '_designatedReporter' ],
//                  signature: [ 'address', 'address', 'address' ],
//                  returns: 'address',
//                  to: undefined } },
//            MailboxFactory:
// ...
//                  address: '0x75228dce4d82566d93068a8d5d49435216551599' },
//               TimestampSet:
//                { contract: 'Augur',
//                  inputs:
//                   [ { indexed: false, name: 'newTimestamp', type: 'uint256' } ],
//                  signature:
//                   '0x11dda748f0bd3af85a073da0088a0acb827d9584a4fdb825c81f1232a5309538',
//                  address: '0x75228dce4d82566d93068a8d5d49435216551599' } },
//            LegacyReputationToken:
//             { FundedAccount:
//                { contract: 'LegacyReputationToken',
//                  inputs:
//                   [ { indexed: true, name: '_universe', type: 'address' },
//                     { indexed: true, name: '_sender', type: 'address' },
//                     { indexed: false, name: '_repBalance', type: 'uint256' },
//                     { indexed: false, name: '_timestamp', type: 'uint256' } ],
//                  signature:
//                   '0xbf88b5a3158512dc8ad44dadf221f46eb1df762a2e7fd1de86aab34b0af455cf',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Pause:
//                { contract: 'LegacyReputationToken',
//                  inputs: [],
//                  signature:
//                   '0x6985a02210a168e66602d3235cb6db0e70f92b3ba4d376a33c0f3d9434bff625',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Unpause:
//                { contract: 'LegacyReputationToken',
//                  inputs: [],
//                  signature:
//                   '0x7805862f689e2f13df9f062ff482ad3ad112aca9e0847911ed832e158c525b33',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Mint:
//                { contract: 'LegacyReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Burn:
//                { contract: 'LegacyReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Approval:
//                { contract: 'LegacyReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' },
//               Transfer:
//                { contract: 'LegacyReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: '0xe94327d07fc17907b4db788e5adf2ed424addff6' } },
//            TestNetReputationToken:
//             { Mint:
//                { contract: 'TestNetReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: undefined },
//               Burn:
//                { contract: 'TestNetReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: undefined },
//               Approval:
//                { contract: 'TestNetReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: undefined },
//               Transfer:
//                { contract: 'TestNetReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: undefined } },
//            DisputeCrowdsourcer:
//             { Mint:
//                { contract: 'DisputeCrowdsourcer',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: undefined },
//               Burn:
//                { contract: 'DisputeCrowdsourcer',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: undefined },
//               Approval:
//                { contract: 'DisputeCrowdsourcer',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: undefined },
//               Transfer:
//                { contract: 'DisputeCrowdsourcer',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: undefined } },
//            FeeToken:
//             { Mint:
//                { contract: 'FeeToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: undefined },
//               Burn:
//                { contract: 'FeeToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: undefined },
//               Approval:
//                { contract: 'FeeToken',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: undefined },
//               Transfer:
//                { contract: 'FeeToken',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: undefined } },
//            FeeWindow:
//             { Mint:
//                { contract: 'FeeWindow',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: undefined },
//               Burn:
//                { contract: 'FeeWindow',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: undefined },
//               Approval:
//                { contract: 'FeeWindow',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: undefined },
//               Transfer:
//                { contract: 'FeeWindow',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: undefined } },
//            ReputationToken:
//             { Mint:
//                { contract: 'ReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: undefined },
//               Burn:
//                { contract: 'ReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: undefined },
//               Approval:
//                { contract: 'ReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: undefined },
//               Transfer:
//                { contract: 'ReputationToken',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: undefined } },
//            Cash:
//             { Mint:
//                { contract: 'Cash',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: '0xd5524179cb7ae012f5b642c1d6d700bbaa76b96b' },
//               Burn:
//                { contract: 'Cash',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: '0xd5524179cb7ae012f5b642c1d6d700bbaa76b96b' },
//               Approval:
//                { contract: 'Cash',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: '0xd5524179cb7ae012f5b642c1d6d700bbaa76b96b' },
//               Transfer:
//                { contract: 'Cash',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: '0xd5524179cb7ae012f5b642c1d6d700bbaa76b96b' } },
//            ShareToken:
//             { Mint:
//                { contract: 'ShareToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x0f6798a560793a54c3bcfe86a93cde1e73087d944c0ea20544137d4121396885',
//                  address: '0x2a21d90745dfed999aa0b6e08d648855c5f14663' },
//               Burn:
//                { contract: 'ShareToken',
//                  inputs:
//                   [ { indexed: true, name: 'target', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xcc16f5dbb4873280815c1ee09dbd06736cffcc184412cf7a71a0fdb75d397ca5',
//                  address: '0x2a21d90745dfed999aa0b6e08d648855c5f14663' },
//               Approval:
//                { contract: 'ShareToken',
//                  inputs:
//                   [ { indexed: true, name: 'owner', type: 'address' },
//                     { indexed: true, name: 'spender', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
//                  address: '0x2a21d90745dfed999aa0b6e08d648855c5f14663' },
//               Transfer:
//                { contract: 'ShareToken',
//                  inputs:
//                   [ { indexed: true, name: 'from', type: 'address' },
//                     { indexed: true, name: 'to', type: 'address' },
//                     { indexed: false, name: 'value', type: 'uint256' } ],
//                  signature:
//                   '0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef',
//                  address: '0x2a21d90745dfed999aa0b6e08d648855c5f14663' } } } } } }

// %%
var universe = myConnectionInfo.ethereumNode.contracts.Universe;
universe
// Out:
// '0xe991247b78f937d7b69cfc00f1a487a293557677'

// %%
var markets;

//var searchString = "category: Ethereum OR tags: ETH"
//var searchString = "category: POLITICS"

augur.markets.getMarkets({
  universe: universe,
  //search: searchString
}, function (error, result) {
  markets = result;
});

// %%
markets.length
// Out:
// 1624

// %%
var outcomeBound = 2;

var i;
var thisID;
var finalizedMarketInfo = [];

for (i = 0; i < markets.length; i++) { 
    thisID = markets[i];
    augur.markets.getMarketsInfo({marketIds: [thisID]}, 
        function (error, result) {if (result[0].finalizationBlockNumber != null && 
                                      result[0].numOutcomes >= outcomeBound)
            {finalizedMarketInfo.push(result[0])}});
}

// %%
finalizedMarketInfo.length

// %%
finalizedMarketInfo

// %%
var marketInfoList = finalizedMarketInfo; // get all markets
//var marketIndex = 5
//var marketInfoList = [finalizedMarketInfo[marketIndex]] // get a single market
var allMarketPriceHistory = [];

marketInfoList.forEach(function(arrayElement) {
  augur.markets.getMarketPriceHistory({marketId: arrayElement.id}, function(error, result) {
    allMarketPriceHistory.push([arrayElement, result]);
  });
});

// %%
allMarketPriceHistory.length

// %%
allMarketPriceHistory

// %%
allMarketPriceHistory[0][1]['1'].length

// %%
var orderBookResults;
var marketID = '0x79ee0681a6090ac5169aaf04422daa8c5cccacb3';

augur.trading.getOrders({
  marketId: marketID,
  universe: universe,
  //outcome: '1',
  //orderType: "buy",
  orderState: "ALL",
}, function (error, result) {
  orderBookResults = result;
});

// %%
orderBookResults['0x79ee0681a6090ac5169aaf04422daa8c5cccacb3']

// %%
Object.keys(orderBookResults['0x79ee0681a6090ac5169aaf04422daa8c5cccacb3']['1'].buy).length
