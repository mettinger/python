# %% [markdown]
# # Begin: run but don't change

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
if sys.platform == 'linux':
    # !pip install openpyxl

# %%
def makeConfusionMatrix(truthName, testName):
    
    notNANs = pd.notnull(df[truthName].values) & pd.notnull(df[testName].values)
    
    true = list(df[truthName].values[notNANs])
    test = list(df[testName].values[notNANs])
    
    cm = confusion_matrix(true, test)
    dispCompact = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['negative', 'positive'])
    dispCompact.plot()
    plt.title('True: %s    Test: %s' % (truthName, testName));

# %%
df = pd.read_excel("Data_ EC-Kit_Products_Evaluation_E Coli Tab Only_3-7-19.xlsx", skiprows=2)
df = df.drop(index=[0])
df = df.drop(index=range(63, 182))
df = df.drop(columns=['Unnamed: 11'])
df.head(n=100)
# Out:
#    Unnamed: 0 IDEXX (Mark, ignore this column) IDEXX Colilert P/A vials  \
# 1         50a                            387.9     1                  0
# 2         50b                             90.9     1                  0
# 3         51a                                0     0                  0
# 4         51b                                0     0                  0
# 5         52a                                0     0                  0
# 6         52b                                1     1                  0
# 7         53a                                2     1                  1
# 8         53b                              4.1     1                  0
# 9         54a                             69.1     1                  1
# 10        54b                             47.1     1                  1
# 11        55a                                0     0                  0
# 12        55b                                0     0                  0
# 13        56a                             9999     1                  1
# 14        56b                           2419.6     1                  1
# 15        57a                                0     0                  0
# 16        57b                                0     0                  0
# 17        58a                                0     0                  0
# 18        58b                                0     0                  0
# 19        59a                             9999     1                  1
# 20        59b                             9999     1                  1
# 21        60a                            139.6     1                  1
# 22        60b                            217.8     1                  1
# 23        71a                             19.7     1                  1
# 24        71b                             35.9     1                  1
# 25        72a                                0     0                  0
# 26        72b                                0     0                  0
# 27        73a                                0     0                  0
# 28        73b                                0     0                  0
# 29        74a                             93.3     1                  1
# 30        74b                               91     1                  1
# 31        75a                             41.1     1                  1
# 32        75b                             52.8     1                  1
# 33        76a                            201.4     1                  1
# 34        76b                            153.9     1                  1
# 35        77a                              4.1     1                  0
# 36        77b                                3     1                  1
# 37        78a                                0     0                  0
# 38        78b                                0     0                  0
# 39        79a                                0     0                  0
# 40        79b                                0     0                  0
# 41        80a                             13.4     1                  1
# 42        80b                             17.5     1                  1
# 43        81a                           1153.1     1                  1
# 44        81b                           2419.6     1                  1
# 45        82a                                2     1                  0
# 46        82b                             26.5     1                  0
# 47        83a                           2419.6     1                  1
# 48        83b                             9999     1                  1
# 49        84a                             9999     1                  1
# 50        84b                           2419.6     1                  1
# 51        85a                                0     0                  0
# 52        85b                                0     0                  0
# 53        86a                                2     1                  0
# 54        86b                                0     0                  0
# 55        87a                            248.9     1                  1
# 56        87b                            222.4     1                  1
# 57        88a                                0     0                  0
# 58        88b                                0     0                  0
# 59        89a                             48.7     1                  0
# 60        89b                             77.1     1                  0
# 61        90a                                0     0                  0
# 62        90b                                0     0                  0
#
#    Compact Dry 1mL ECC 1 mL, 24 hr ECC 10mL 24 hr  RUG 24 hr RUG 48 hr  \
# 1                1               1              1          1         1
# 2                1               1              1          1         1
# 3                0               0              0          0         0
# 4                0               0              0          0         0
# 5                0               0              0          0         0
# 6                0               0              0          0         0
# 7                0               0              1          0         1
# 8                1               0              1          1         1
# 9                0               0              1          1         1
# 10               1               0              1        NaN         1
# 11               0               0              1          0         0
# 12               0               0              1          0         1
# 13               1               1              1          1         1
# 14               1               1              1          1         1
# 15               0               0              0          0         0
# 16               0               0              1          0         0
# 17               0               0              1          0         0
# 18               0               0              1          0         0
# 19               1               1              1          1         1
# 20               1               1              1          1         1
# 21               1               1              1          1         1
# 22               1               1              1          1         1
# 23               1               1              1          0         0
# 24               0               1              1          0         0
# 25               0               0              0          0         0
# 26               0               0              1          0         0
# 27               0               0              0          0         0
# 28               0               0              0          0         0
# 29               1               1              1          1         1
# 30               1               1              1          1         1
# 31               0               1              1          1         1
# 32               1               1              1          1         1
# 33               1               1              1          1         1
# 34               1               1              1          1         1
# 35               0               0              1          1         1
# 36               0               0              1          1         1
# 37               0               0              0          0         0
# 38               0               0              0          0         0
# 39               0               0              1          0         0
# 40               0               0              1          0         0
# 41               0               1              1          1         1
# 42               1               1              1          1         1
# 43             NaN               0              1          1         1
# 44             NaN               0              0          1         1
# 45             NaN               0              0          0         0
# 46             NaN               0              0          1         1
# 47             NaN               0              1          1         1
# 48             NaN               0              1          1         1
# 49             NaN               1              1          1         1
# 50             NaN               1              1          1         1
# 51             NaN               0              0          0         0
# 52             NaN               0              0          0         0
# 53             NaN               0              1          1         1
# 54             NaN               0              0          1         1
# 55             NaN               0              1          1         1
# 56             NaN               1              1          1         1
# 57             NaN               1              0          0         0
# 58             NaN               0              0          0         0
# 59             NaN               1              0          0         0
# 60             NaN               0              1          1         1
# 61             NaN               0              0          0         0
# 62             NaN               0              0          0         0
#
#    ECC 1 mL 48 hr ECC 10mL 48 hr
# 1               1              1
# 2               1              1
# 3               0              1
# 4               0              1
# 5               0              0
# 6               0              0
# 7               0              1
# 8               0              1
# 9               0              1
# 10              0              1
# 11              1              1
# 12              0              1
# 13              1              1
# 14              1              1
# 15              0              1
# 16              1              1
# 17              0              1
# 18              0              1
# 19              1              1
# 20              1              1
# 21              1              1
# 22              1              1
# 23              1              1
# 24              1              1
# 25              0              0
# 26              0              1
# 27              0              0
# 28              0              0
# 29              1              1
# 30              1              1
# 31              1              1
# 32              1              1
# 33              1              1
# 34              1              1
# 35              1              1
# 36              0              1
# 37              0              0
# 38              0              0
# 39              0              1
# 40              0              1
# 41              1              1
# 42              1              1
# 43              0              1
# 44              0              0
# 45              0              0
# 46              0              0
# 47              0              1
# 48              0              1
# 49              1              1
# 50              1              1
# 51              0              0
# 52              0              0
# 53            NaN              1
# 54              1              0
# 55              0              1
# 56              1              1
# 57              0              0
# 58              0              0
# 59              1              0
# 60              0              1
# 61              0              0
# 62              0              0

# %% [markdown]
# # End: run but don't change

# %% [markdown]
# # Here are the names to use for truth and test:

# %%
df.columns[2:]
# Out:
# Index(['IDEXX', 'Colilert P/A vials', 'Compact Dry 1mL', 'ECC 1 mL, 24 hr',
#        'ECC 10mL 24 hr', ' RUG 24 hr', 'RUG 48 hr', 'ECC 1 mL 48 hr',
#        'ECC 10mL 48 hr'],
#       dtype='object')

# %% [markdown]
# # Choose ground truth and test here from names above:

# %%
truthName = 'IDEXX'
testName = 'ECC 1 mL, 24 hr'

# %% [markdown]
# # Plot the confusion matrix here:

# %%
makeConfusionMatrix(truthName = truthName,  testName = testName)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-05d6c189298c> in <module>
# ----> 1 makeConfusionMatrix(truthName = truthName,  testName = testName)
#
# <ipython-input-111-d744c75ae2fa> in makeConfusionMatrix(truthName, testName)
#       8     cm = confusion_matrix(true, test)
#       9     dispCompact = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['negative', 'positive'])
# ---> 10     dispCompact.plot(figsize=(10,10))
#      11     plt.title('True: %s    Test: %s' % (truthName, testName));
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: plot() got an unexpected keyword argument 'figsize'
