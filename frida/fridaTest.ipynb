# %%
import frida
import sys

# %%
jscode = '''
send(Module.enumerateExports("libnative-lib.so"))
'''

# %%
a = frida.get_usb_device()
a.enumerate_processes()
# Out:
# [Process(pid=1, name="init", parameters={}),
#  Process(pid=142, name="init", parameters={}),
#  Process(pid=144, name="ueventd", parameters={}),
#  Process(pid=169, name="logd", parameters={}),
#  Process(pid=170, name="lmkd", parameters={}),
#  Process(pid=171, name="servicemanager", parameters={}),
#  Process(pid=173, name="hwservicemanager", parameters={}),
#  Process(pid=178, name="sh", parameters={}),
#  Process(pid=179, name="qemu-props", parameters={}),
#  Process(pid=182, name="vold", parameters={}),
#  Process(pid=190, name="android.hardware.keymaster@4.1-service", parameters={}),
#  Process(pid=205, name="android.system.suspend@1.0-service", parameters={}),
#  Process(pid=206, name="android.hardware.atrace@1.0-service", parameters={}),
#  Process(pid=271, name="createns", parameters={}),
#  Process(pid=276, name="tombstoned", parameters={}),
#  Process(pid=282, name="statsd", parameters={}),
#  Process(pid=283, name="netd", parameters={}),
#  Process(pid=284, name="zygote", parameters={}),
#  Process(pid=288, name="android.hidl.allocator@1.0-service", parameters={}),
#  Process(pid=289, name="android.hardware.audio.service.ranchu", parameters={}),
#  Process(pid=290, name="android.hardware.authsecret@1.0-service", parameters={}),
#  Process(pid=291, name="android.hardware.bluetooth@1.1-service.sim", parameters={}),
#  Process(pid=292, name="android.hardware.camera.provider@2.4-service", parameters={}),
#  Process(pid=293, name="android.hardware.camera.provider@2.6-service-google", parameters={}),
#  Process(pid=294, name="android.hardware.cas@1.2-service", parameters={}),
#  Process(pid=295, name="android.hardware.contexthub@1.1-service.mock", parameters={}),
#  Process(pid=296, name="android.hardware.drm@1.0-service", parameters={}),
#  Process(pid=297, name="iptables-restore", parameters={}),
#  Process(pid=298, name="ip6tables-restore", parameters={}),
#  Process(pid=299, name="android.hardware.drm@1.3-service.clearkey", parameters={}),
#  Process(pid=300, name="android.hardware.drm@1.3-service.widevine", parameters={}),
#  Process(pid=302, name="android.hardware.gatekeeper@1.0-service.software", parameters={}),
#  Process(pid=303, name="android.hardware.graphics.allocator@3.0-service", parameters={}),
#  Process(pid=304, name="android.hardware.graphics.composer@2.3-service", parameters={}),
#  Process(pid=305, name="android.hardware.health@2.1-service", parameters={}),
#  Process(pid=307, name="android.hardware.neuralnetworks@1.3-service-sample-all", parameters={}),
#  Process(pid=309, name="android.hardware.neuralnetworks@1.3-service-sample-float-fast", parameters={}),
#  Process(pid=310, name="android.hardware.neuralnetworks@1.3-service-sample-float-slow", parameters={}),
#  Process(pid=313, name="android.hardware.neuralnetworks@1.3-service-sample-minimal", parameters={}),
#  Process(pid=319, name="android.hardware.neuralnetworks@1.3-service-sample-quant", parameters={}),
#  Process(pid=320, name="android.hardware.power.stats@1.0-service.mock", parameters={}),
#  Process(pid=322, name="android.hardware.sensors@2.1-service.multihal", parameters={}),
#  Process(pid=327, name="android.hardware.thermal@2.0-service.mock", parameters={}),
#  Process(pid=330, name="android.hardware.usb@1.0-service", parameters={}),
#  Process(pid=331, name="android.hardware.wifi@1.0-service", parameters={}),
#  Process(pid=334, name="android.hardware.identity-service.example", parameters={}),
#  Process(pid=337, name="android.hardware.lights-service.example", parameters={}),
#  Process(pid=339, name="android.hardware.power-service.example", parameters={}),
#  Process(pid=341, name="android.hardware.rebootescrow-service.default", parameters={}),
#  Process(pid=343, name="android.hardware.vibrator-service.example", parameters={}),
#  Process(pid=345, name="media.log", parameters={}),
#  Process(pid=348, name="credstore", parameters={}),
#  Process(pid=352, name="gpuservice", parameters={}),
#  Process(pid=364, name="surfaceflinger", parameters={}),
#  Process(pid=371, name="logcat", parameters={}),
#  Process(pid=375, name="audioserver", parameters={}),
#  Process(pid=382, name="adbd", parameters={}),
#  Process(pid=391, name="traced_probes", parameters={}),
#  Process(pid=394, name="traced", parameters={}),
#  Process(pid=403, name="cameraserver", parameters={}),
#  Process(pid=405, name="drmserver", parameters={}),
#  Process(pid=412, name="incidentd", parameters={}),
#  Process(pid=415, name="installd", parameters={}),
#  Process(pid=416, name="iorapd", parameters={}),
#  Process(pid=417, name="keystore", parameters={}),
#  Process(pid=424, name="media.extractor", parameters={}),
#  Process(pid=425, name="media.metrics", parameters={}),
#  Process(pid=428, name="mediaserver", parameters={}),
#  Process(pid=430, name="storaged", parameters={}),
#  Process(pid=431, name="wificond", parameters={}),
#  Process(pid=435, name="media.codec", parameters={}),
#  Process(pid=436, name="libgoldfish-rild", parameters={}),
#  Process(pid=440, name="media.swcodec", parameters={}),
#  Process(pid=445, name="mdnsd", parameters={}),
#  Process(pid=452, name="gatekeeperd", parameters={}),
#  Process(pid=462, name="android.hardware.biometrics.face@1.0-service.example", parameters={}),
#  Process(pid=464, name="android.hardware.biometrics.fingerprint@2.1-service", parameters={}),
#  Process(pid=472, name="llkd", parameters={}),
#  Process(pid=487, name="netmgr", parameters={}),
#  Process(pid=492, name="wifi_forwarder", parameters={}),
#  Process(pid=508, name="hostapd_nohidl", parameters={}),
#  Process(pid=520, name="dhcpclient", parameters={}),
#  Process(pid=583, name="system_server", parameters={}),
#  Process(pid=685, name="android.hardware.input.classifier@1.0-service.default", parameters={}),
#  Process(pid=696, name="iorap.prefetcherd", parameters={}),
#  Process(pid=753, name="wpa_supplicant", parameters={}),
#  Process(pid=755, name="com.android.bluetooth", parameters={}),
#  Process(pid=778, name="com.android.systemui", parameters={}),
#  Process(pid=840, name="android.hardware.gnss@2.0-service.ranchu", parameters={}),
#  Process(pid=881, name="webview_zygote", parameters={}),
#  Process(pid=906, name="com.android.networkstack.process", parameters={}),
#  Process(pid=967, name="com.android.se", parameters={}),
#  Process(pid=995, name="com.android.phone", parameters={}),
#  Process(pid=1043, name="android.ext.services", parameters={}),
#  Process(pid=1119, name="com.android.launcher3", parameters={}),
#  Process(pid=1263, name="com.google.android.gms.persistent", parameters={}),
#  Process(pid=1313, name="com.android.inputmethod.latin", parameters={}),
#  Process(pid=1435, name="com.google.android.gms", parameters={}),
#  Process(pid=1456, name="com.google.process.gservices", parameters={}),
#  Process(pid=1475, name="com.android.providers.media.module", parameters={}),
#  Process(pid=1509, name="com.android.ims.rcsservice", parameters={}),
#  Process(pid=1549, name="com.android.emulator.multidisplay", parameters={}),
#  Process(pid=2221, name="com.android.providers.calendar", parameters={}),
#  Process(pid=3057, name="Clock", parameters={}),
#  Process(pid=3703, name="Sieve", parameters={}),
#  Process(pid=4894, name="com.android.permissioncontroller", parameters={}),
#  Process(pid=5020, name="abb", parameters={}),
#  Process(pid=5046, name="com.android.packageinstaller", parameters={}),
#  Process(pid=5060, name="android.process.acore", parameters={}),
#  Process(pid=5339, name="android.process.media", parameters={}),
#  Process(pid=5683, name="ndkfrida", parameters={}),
#  Process(pid=5797, name="logcat", parameters={}),
#  Process(pid=5821, name="sh", parameters={}),
#  Process(pid=5823, name="sh", parameters={}),
#  Process(pid=5827, name="Calendar", parameters={}),
#  Process(pid=5860, name="frida-server-16.1.4-android-x86", parameters={}),
#  Process(pid=5862, name="logcat", parameters={})]

# %%
def on_message(message, data):

    global result
    #print(message)
    result = message

# %%
result = ''
process = frida.get_usb_device().attach('ndkfrida')
script = process.create_script(jscode)
script.on('message', on_message)
script.load()
#sys.stdin.read()

# %%
result
# Out:
# {'type': 'send',
#  'payload': [{'type': 'variable',
#    'name': '_ZTSN10__cxxabiv117__array_type_infoE',
#    'address': '0xc096f1a0'},
#   {'type': 'function',
#    'name': '__cxa_call_unexpected',
#    'address': '0xc0950070'},
#   {'type': 'function',
#    'name': '_ZNSt12length_errorD1Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv123__fundamental_type_infoE',
#    'address': '0xc0977710'},
#   {'type': 'variable', 'name': '_ZTIPDn', 'address': '0xc0977768'},
#   {'type': 'function',
#    'name': '__cxa_free_exception',
#    'address': '0xc094eb80'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv117__array_type_infoE',
#    'address': '0xc0977b3c'},
#   {'type': 'function',
#    'name': '_ZN10__cxxabiv119__setExceptionClassEP17_Unwind_Exceptiony',
#    'address': '0xc094eab0'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC2EPKc',
#    'address': '0xc094e7d0'},
#   {'type': 'function',
#    'name': '_ZN10__cxxabiv121__isOurExceptionClassEPK17_Unwind_Exception',
#    'address': '0xc094eaf0'},
#   {'type': 'variable', 'name': '_ZTIPDs', 'address': '0xc0977ad8'},
#   {'type': 'variable', 'name': '_ZTIPDu', 'address': '0xc0977ab0'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv129__pointer_to_member_type_infoE',
#    'address': '0xc0977c54'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk117_DeallocateCaller27__do_deallocate_handle_sizeEPvj',
#    'address': '0xc094d430'},
#   {'type': 'function', 'name': '_ZdlPvj', 'address': '0xc094e3b0'},
#   {'type': 'variable', 'name': '__cxa_new_handler', 'address': '0xc0978048'},
#   {'type': 'function',
#    'name': '_ZNSt10bad_typeidD2Ev',
#    'address': '0xc0968ec0'},
#   {'type': 'function',
#    'name': '_ZnwjSt11align_val_t',
#    'address': '0xc094e470'},
#   {'type': 'function',
#    'name': '_ZNSt13bad_exceptionD1Ev',
#    'address': '0xc0950910'},
#   {'type': 'variable',
#    'name': '_ZTVSt15underflow_error',
#    'address': '0xc0976744'},
#   {'type': 'function',
#    'name': '_ZdaPvSt11align_val_t',
#    'address': '0xc094e6a0'},
#   {'type': 'variable', 'name': '_ZTVSt11range_error', 'address': '0xc09766f8'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC1ERKS_',
#    'address': '0xc094e860'},
#   {'type': 'function',
#    'name': 'Java_com_apphacking_ndkfrida_MainActivity_decryptString',
#    'address': '0xc094cce0'},
#   {'type': 'function', 'name': '_ZnwjRKSt9nothrow_t', 'address': '0xc094e280'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv123__fundamental_type_infoE',
#    'address': '0xc096f088'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC1EPKc',
#    'address': '0xc094e990'},
#   {'type': 'function',
#    'name': '__gxx_personality_v0',
#    'address': '0xc094f780'},
#   {'type': 'function', 'name': '__cxa_throw', 'address': '0xc094ecb0'},
#   {'type': 'variable',
#    'name': '_ZTISt12length_error',
#    'address': '0xc09766cc'},
#   {'type': 'function', 'name': '_ZnajRKSt9nothrow_t', 'address': '0xc094e300'},
#   {'type': 'function', 'name': '_ZNSt9bad_allocC2Ev', 'address': '0xc09509c0'},
#   {'type': 'function',
#    'name': '_ZNSt12domain_errorD0Ev',
#    'address': '0xc0950c40'},
#   {'type': 'variable',
#    'name': '_ZTSSt16invalid_argument',
#    'address': '0xc096d24e'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv116__enum_type_infoE',
#    'address': '0xc096f1c2'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk111char_traitsIcE6assignERcRKc',
#    'address': '0xc094dc00'},
#   {'type': 'variable',
#    'name': '_ZTSSt12out_of_range',
#    'address': '0xc096d274'},
#   {'type': 'function',
#    'name': '_ZNSt12length_errorD2Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTISt8bad_cast', 'address': '0xc0977cb0'},
#   {'type': 'variable', 'name': '_ZTVSt9bad_alloc', 'address': '0xc09765c8'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv121__vmi_class_type_infoE',
#    'address': '0xc0977be8'},
#   {'type': 'function',
#    'name': '_ZdaPvjSt11align_val_t',
#    'address': '0xc094e700'},
#   {'type': 'function',
#    'name': '_ZSt14set_unexpectedPFvvE',
#    'address': '0xc0950f60'},
#   {'type': 'function', 'name': '_ZdlPv', 'address': '0xc094e350'},
#   {'type': 'function',
#    'name': '_ZNKSt13bad_exception4whatEv',
#    'address': '0xc09509a0'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC2ERKS_',
#    'address': '0xc094ea20'},
#   {'type': 'function',
#    'name': '__cxa_uncaught_exceptions',
#    'address': '0xc094f3c0'},
#   {'type': 'variable',
#    'name': '_ZTISt16invalid_argument',
#    'address': '0xc09766ac'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_erroraSERKS_',
#    'address': '0xc094e8a0'},
#   {'type': 'function',
#    'name': '_ZdlPvSt11align_val_tRKSt9nothrow_t',
#    'address': '0xc094e640'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC1ERKNSt6__ndk112basic_stringIcNS0_11char_traitsIcEENS0_9allocatorIcEEEE',
#    'address': '0xc094e8f0'},
#   {'type': 'function',
#    'name': '__cxa_current_exception_type',
#    'address': '0xc094ef90'},
#   {'type': 'function',
#    'name': '_ZNSt13bad_exceptionD2Ev',
#    'address': '0xc0950910'},
#   {'type': 'function',
#    'name': '_ZN7_JNIEnv12NewStringUTFEPKc',
#    'address': '0xc094d010'},
#   {'type': 'function', 'name': '_ZSt10unexpectedv', 'address': '0xc094f670'},
#   {'type': 'variable', 'name': '_ZTIa', 'address': '0xc0977828'},
#   {'type': 'function',
#    'name': '_ZNKSt6__ndk121__basic_string_commonILb1EE20__throw_length_errorEv',
#    'address': '0xc094d860'},
#   {'type': 'variable', 'name': '_ZTIb', 'address': '0xc0977788'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv121__vmi_class_type_infoE',
#    'address': '0xc096f208'},
#   {'type': 'variable', 'name': '_ZTIc', 'address': '0xc09777d8'},
#   {'type': 'variable', 'name': '_ZTId', 'address': '0xc0977a30'},
#   {'type': 'variable', 'name': '_ZTIe', 'address': '0xc0977a58'},
#   {'type': 'variable', 'name': '_ZTIf', 'address': '0xc0977a08'},
#   {'type': 'variable', 'name': '_ZTIg', 'address': '0xc0977a80'},
#   {'type': 'variable', 'name': '_ZTIh', 'address': '0xc0977800'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv129__pointer_to_member_type_infoE',
#    'address': '0xc096f04b'},
#   {'type': 'function',
#    'name': '__cxa_rethrow_primary_exception',
#    'address': '0xc094f180'},
#   {'type': 'variable', 'name': '_ZTIi', 'address': '0xc09778a0'},
#   {'type': 'function', 'name': '_ZNSt9type_infoD0Ev', 'address': '0xc0968da0'},
#   {'type': 'variable',
#    'name': '_ZTSSt15underflow_error',
#    'address': '0xc096d2ba'},
#   {'type': 'variable', 'name': '_ZTIj', 'address': '0xc09778c8'},
#   {'type': 'variable', 'name': '_ZTIl', 'address': '0xc09778f0'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv120__si_class_type_infoE',
#    'address': '0xc0977bb4'},
#   {'type': 'function',
#    'name': '_ZNSt12domain_errorD1Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTIm', 'address': '0xc0977918'},
#   {'type': 'variable', 'name': '_ZTIn', 'address': '0xc0977990'},
#   {'type': 'function', 'name': '_ZNSt8bad_castD0Ev', 'address': '0xc0968e30'},
#   {'type': 'variable', 'name': '_ZTISt10bad_typeid', 'address': '0xc0977cbc'},
#   {'type': 'variable', 'name': '_ZTVSt8bad_cast', 'address': '0xc0977c70'},
#   {'type': 'function', 'name': '_ZNSt9exceptionD0Ev', 'address': '0xc0950920'},
#   {'type': 'variable', 'name': '_ZTIo', 'address': '0xc09779b8'},
#   {'type': 'function',
#    'name': '_ZNSt10bad_typeidC1Ev',
#    'address': '0xc0968e90'},
#   {'type': 'variable', 'name': '_ZTSPKa', 'address': '0xc096f0ee'},
#   {'type': 'variable', 'name': '_ZTSPKb', 'address': '0xc096f0ca'},
#   {'type': 'variable', 'name': '_ZTSSt10bad_typeid', 'address': '0xc096f247'},
#   {'type': 'variable', 'name': '_ZTIs', 'address': '0xc0977850'},
#   {'type': 'variable', 'name': '_ZTSPKc', 'address': '0xc096f0dc'},
#   {'type': 'function',
#    'name': '_ZSt13set_terminatePFvvE',
#    'address': '0xc0950f90'},
#   {'type': 'variable', 'name': '_ZTIt', 'address': '0xc0977878'},
#   {'type': 'variable', 'name': '_ZTSPKd', 'address': '0xc096f166'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEC2IDnEEPKc',
#    'address': '0xc094cf50'},
#   {'type': 'variable', 'name': '_ZTSPKe', 'address': '0xc096f16f'},
#   {'type': 'function',
#    'name': '_ZSt17__throw_bad_allocv',
#    'address': '0xc094e1a0'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC2EPKc',
#    'address': '0xc094e990'},
#   {'type': 'variable', 'name': '_ZTIv', 'address': '0xc0977738'},
#   {'type': 'variable', 'name': '_ZTSPKf', 'address': '0xc096f15d'},
#   {'type': 'variable',
#    'name': '_ZTSSt20bad_array_new_length',
#    'address': '0xc096d214'},
#   {'type': 'variable',
#    'name': '_ZTVSt16invalid_argument',
#    'address': '0xc0976698'},
#   {'type': 'variable', 'name': '_ZTIw', 'address': '0xc09777b0'},
#   {'type': 'variable', 'name': '_ZTSPKg', 'address': '0xc096f178'},
#   {'type': 'variable', 'name': '_ZTSPa', 'address': '0xc096f0eb'},
#   {'type': 'variable',
#    'name': '_ZTVSt12length_error',
#    'address': '0xc09766b8'},
#   {'type': 'variable', 'name': '_ZTIx', 'address': '0xc0977940'},
#   {'type': 'variable', 'name': '_ZTSPKh', 'address': '0xc096f0e5'},
#   {'type': 'variable', 'name': '_ZTSPb', 'address': '0xc096f0c7'},
#   {'type': 'variable', 'name': '_ZTIy', 'address': '0xc0977968'},
#   {'type': 'variable', 'name': '_ZTSPKi', 'address': '0xc096f109'},
#   {'type': 'variable', 'name': '_ZTSPc', 'address': '0xc096f0d9'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv121__vmi_class_type_infoE',
#    'address': '0xc0977c10'},
#   {'type': 'variable', 'name': '_ZTSPKj', 'address': '0xc096f112'},
#   {'type': 'variable', 'name': '_ZTSPd', 'address': '0xc096f163'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv123__fundamental_type_infoE',
#    'address': '0xc097772c'},
#   {'type': 'variable', 'name': '_ZTSPe', 'address': '0xc096f16c'},
#   {'type': 'function',
#    'name': '_ZNKSt10bad_typeid4whatEv',
#    'address': '0xc0968f30'},
#   {'type': 'function',
#    'name': '_ZNSt20bad_array_new_lengthD0Ev',
#    'address': '0xc0950a70'},
#   {'type': 'variable', 'name': '_ZTSPKl', 'address': '0xc096f11b'},
#   {'type': 'variable', 'name': '_ZTSPf', 'address': '0xc096f15a'},
#   {'type': 'function',
#    'name': '_ZNKSt8bad_cast4whatEv',
#    'address': '0xc0968e70'},
#   {'type': 'function', 'name': '_ZSt9terminatev', 'address': '0xc094f5e0'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv117__class_type_infoE',
#    'address': '0xc0977b8c'},
#   {'type': 'function',
#    'name': '_ZNSt14overflow_errorD0Ev',
#    'address': '0xc0950e20'},
#   {'type': 'variable', 'name': '_ZTSPKm', 'address': '0xc096f124'},
#   {'type': 'variable', 'name': '_ZTSPg', 'address': '0xc096f175'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv117__pbase_type_infoE',
#    'address': '0xc096efe0'},
#   {'type': 'variable', 'name': '_ZTSPKn', 'address': '0xc096f13f'},
#   {'type': 'variable', 'name': '_ZTSPh', 'address': '0xc096f0e2'},
#   {'type': 'variable',
#    'name': '_ZTISt13bad_exception',
#    'address': '0xc0976620'},
#   {'type': 'variable', 'name': '_ZTSPKo', 'address': '0xc096f148'},
#   {'type': 'variable', 'name': '_ZTSPi', 'address': '0xc096f106'},
#   {'type': 'variable', 'name': '_ZTSSt9type_info', 'address': '0xc096f22e'},
#   {'type': 'variable', 'name': '_ZTSPj', 'address': '0xc096f10f'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv120__function_type_infoE',
#    'address': '0xc0977b48'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv117__pbase_type_infoE',
#    'address': '0xc09776c4'},
#   {'type': 'variable', 'name': '_ZTSPl', 'address': '0xc096f118'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv116__shim_type_infoE',
#    'address': '0xc09776ac'},
#   {'type': 'variable', 'name': '_ZTSPKs', 'address': '0xc096f0f7'},
#   {'type': 'variable', 'name': '_ZTSPm', 'address': '0xc096f121'},
#   {'type': 'variable', 'name': '_ZTSPKt', 'address': '0xc096f100'},
#   {'type': 'variable', 'name': '_ZTSPn', 'address': '0xc096f13c'},
#   {'type': 'function',
#    'name': '_ZSt14get_unexpectedv',
#    'address': '0xc094f5c0'},
#   {'type': 'variable', 'name': '_ZTSPo', 'address': '0xc096f145'},
#   {'type': 'variable', 'name': '_ZTSPKv', 'address': '0xc096f0b5'},
#   {'type': 'variable', 'name': '_ZTSSt9exception', 'address': '0xc096d1e8'},
#   {'type': 'variable', 'name': '_ZTSPKw', 'address': '0xc096f0d3'},
#   {'type': 'variable', 'name': '_ZTSPKx', 'address': '0xc096f12d'},
#   {'type': 'function',
#    'name': '_ZNKSt20bad_array_new_length4whatEv',
#    'address': '0xc0950aa0'},
#   {'type': 'variable', 'name': '_ZTSPKy', 'address': '0xc096f136'},
#   {'type': 'variable', 'name': '_ZTSPs', 'address': '0xc096f0f4'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk111char_traitsIcE4copyEPcPKcj',
#    'address': '0xc094daf0'},
#   {'type': 'variable', 'name': '_ZTSPt', 'address': '0xc096f0fd'},
#   {'type': 'function',
#    'name': '__cxa_increment_exception_refcount',
#    'address': '0xc094f0e0'},
#   {'type': 'variable', 'name': '_ZTSPv', 'address': '0xc096f0b2'},
#   {'type': 'variable', 'name': '_ZTSPw', 'address': '0xc096f0d0'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6__initEPKcj',
#    'address': '0xc094d590'},
#   {'type': 'variable', 'name': '_ZTSPx', 'address': '0xc096f12a'},
#   {'type': 'function', 'name': '_ZNSt9type_infoD1Ev', 'address': '0xc0968d90'},
#   {'type': 'variable', 'name': '_ZTSPy', 'address': '0xc096f133'},
#   {'type': 'function',
#    'name': '_ZNSt12domain_errorD2Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC1ERKS_',
#    'address': '0xc094ea20'},
#   {'type': 'variable',
#    'name': '_ZTSSt13bad_exception',
#    'address': '0xc096d1f5'},
#   {'type': 'function', 'name': '_ZNSt8bad_castD1Ev', 'address': '0xc0968e00'},
#   {'type': 'function', 'name': '_ZNSt9exceptionD1Ev', 'address': '0xc0950910'},
#   {'type': 'variable',
#    'name': '_ZTSSt12length_error',
#    'address': '0xc096d263'},
#   {'type': 'variable', 'name': '_ZTIDh', 'address': '0xc09779e0'},
#   {'type': 'function',
#    'name': '_ZNSt10bad_typeidC2Ev',
#    'address': '0xc0968e90'},
#   {'type': 'variable', 'name': '_ZTIDi', 'address': '0xc0977af8'},
#   {'type': 'variable', 'name': '_ZTSPDh', 'address': '0xc096f14f'},
#   {'type': 'function',
#    'name': '__cxa_uncaught_exception',
#    'address': '0xc094f380'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorD0Ev',
#    'address': '0xc0950bd0'},
#   {'type': 'variable', 'name': '_ZTSPDi', 'address': '0xc096f197'},
#   {'type': 'variable', 'name': '_ZTIDn', 'address': '0xc0977760'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv116__shim_type_infoE',
#    'address': '0xc09776f4'},
#   {'type': 'variable', 'name': '_ZTSPDn', 'address': '0xc096f0bc'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk117_DeallocateCaller9__do_callEPv',
#    'address': '0xc094d470'},
#   {'type': 'variable', 'name': '_ZTIDs', 'address': '0xc0977ad0'},
#   {'type': 'function',
#    'name': '_ZdaPvRKSt9nothrow_t',
#    'address': '0xc094e410'},
#   {'type': 'function',
#    'name': '_ZNSt20bad_array_new_lengthD1Ev',
#    'address': '0xc0950910'},
#   {'type': 'variable', 'name': '_ZTVSt10bad_typeid', 'address': '0xc0977c84'},
#   {'type': 'function',
#    'name': '_ZNSt14overflow_errorD1Ev',
#    'address': '0xc0950b80'},
#   {'type': 'variable', 'name': '_ZTIDu', 'address': '0xc0977aa8'},
#   {'type': 'variable', 'name': '_ZTSPDs', 'address': '0xc096f18b'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv119__pointer_type_infoE',
#    'address': '0xc09776d0'},
#   {'type': 'variable', 'name': '_ZTSa', 'address': '0xc096f0e9'},
#   {'type': 'function',
#    'name': '_ZNSt15underflow_errorD0Ev',
#    'address': '0xc0950e80'},
#   {'type': 'variable',
#    'name': '_ZTVSt14overflow_error',
#    'address': '0xc0976724'},
#   {'type': 'variable', 'name': '_ZTSPDu', 'address': '0xc096f17f'},
#   {'type': 'variable', 'name': '_ZTSb', 'address': '0xc096f0c5'},
#   {'type': 'variable', 'name': '_ZTSc', 'address': '0xc096f0d7'},
#   {'type': 'function', 'name': '_ZNSt9bad_allocD0Ev', 'address': '0xc09509f0'},
#   {'type': 'variable', 'name': '_ZTSd', 'address': '0xc096f161'},
#   {'type': 'variable', 'name': '_ZTSe', 'address': '0xc096f16a'},
#   {'type': 'variable', 'name': '_ZTSf', 'address': '0xc096f158'},
#   {'type': 'variable',
#    'name': '_ZTSSt13runtime_error',
#    'address': '0xc096d295'},
#   {'type': 'variable', 'name': '_ZTSg', 'address': '0xc096f173'},
#   {'type': 'variable', 'name': '_ZTSh', 'address': '0xc096f0e0'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv119__pointer_type_infoE',
#    'address': '0xc096f002'},
#   {'type': 'variable', 'name': '_ZTSi', 'address': '0xc096f104'},
#   {'type': 'variable', 'name': '_ZTSj', 'address': '0xc096f10d'},
#   {'type': 'function', 'name': '__cxa_rethrow', 'address': '0xc094efe0'},
#   {'type': 'variable',
#    'name': '_ZTISt12domain_error',
#    'address': '0xc097668c'},
#   {'type': 'variable', 'name': '_ZTSl', 'address': '0xc096f116'},
#   {'type': 'variable', 'name': '_ZTISt9type_info', 'address': '0xc0977ca8'},
#   {'type': 'variable', 'name': '_ZTSm', 'address': '0xc096f11f'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk111char_traitsIcE6lengthEPKc',
#    'address': '0xc094d740'},
#   {'type': 'function', 'name': '__cxa_end_catch', 'address': '0xc094ee80'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv120__si_class_type_infoE',
#    'address': '0xc0977bdc'},
#   {'type': 'variable', 'name': '_ZTSn', 'address': '0xc096f13a'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_erroraSERKS_',
#    'address': '0xc094ea60'},
#   {'type': 'function',
#    'name': '_ZSt13get_terminatev',
#    'address': '0xc094f6a0'},
#   {'type': 'variable', 'name': '_ZTSo', 'address': '0xc096f143'},
#   {'type': 'variable',
#    'name': '__cxa_unexpected_handler',
#    'address': '0xc0978008'},
#   {'type': 'function', 'name': '_ZNSt9type_infoD2Ev', 'address': '0xc0968d90'},
#   {'type': 'function',
#    'name': '_ZSt15set_new_handlerPFvvE',
#    'address': '0xc094f730'},
#   {'type': 'variable', 'name': '_ZTSSt9bad_alloc', 'address': '0xc096d207'},
#   {'type': 'variable', 'name': '_ZTSs', 'address': '0xc096f0f2'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorD0Ev',
#    'address': '0xc0950b10'},
#   {'type': 'variable', 'name': '_ZTSt', 'address': '0xc096f0fb'},
#   {'type': 'variable', 'name': '_ZTISt9exception', 'address': '0xc0976604'},
#   {'type': 'variable',
#    'name': '_ZTISt13runtime_error',
#    'address': '0xc097670c'},
#   {'type': 'function', 'name': '_ZNSt8bad_castD2Ev', 'address': '0xc0968e00'},
#   {'type': 'function', 'name': '_ZNSt9exceptionD2Ev', 'address': '0xc0950910'},
#   {'type': 'variable', 'name': '_ZTSv', 'address': '0xc096f0b0'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC2ERKNSt6__ndk112basic_stringIcNS0_11char_traitsIcEENS0_9allocatorIcEEEE',
#    'address': '0xc094e730'},
#   {'type': 'function',
#    'name': '_ZNSt11range_errorD0Ev',
#    'address': '0xc0950dc0'},
#   {'type': 'variable', 'name': '_ZTSw', 'address': '0xc096f0ce'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv117__array_type_infoE',
#    'address': '0xc0977b20'},
#   {'type': 'function', 'name': '__dynamic_cast', 'address': '0xc0968100'},
#   {'type': 'function',
#    'name': '_ZNSt12out_of_rangeD0Ev',
#    'address': '0xc0950d60'},
#   {'type': 'variable', 'name': '_ZTSx', 'address': '0xc096f128'},
#   {'type': 'variable', 'name': '_ZTSy', 'address': '0xc096f131'},
#   {'type': 'variable', 'name': '_ZTSSt8bad_cast', 'address': '0xc096f23b'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorD1Ev',
#    'address': '0xc0950b80'},
#   {'type': 'function',
#    'name': '_ZnajSt11align_val_t',
#    'address': '0xc094e590'},
#   {'type': 'variable',
#    'name': '__cxa_terminate_handler',
#    'address': '0xc0978004'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv120__function_type_infoE',
#    'address': '0xc09776dc'},
#   {'type': 'function',
#    'name': '_ZNSt20bad_array_new_lengthD2Ev',
#    'address': '0xc0950910'},
#   {'type': 'function',
#    'name': '_ZNSt14overflow_errorD2Ev',
#    'address': '0xc0950b80'},
#   {'type': 'function',
#    'name': '__cxa_allocate_exception',
#    'address': '0xc094eb20'},
#   {'type': 'function',
#    'name': '_ZNSt16invalid_argumentD0Ev',
#    'address': '0xc0950ca0'},
#   {'type': 'function',
#    'name': '_ZNSt15underflow_errorD1Ev',
#    'address': '0xc0950b80'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv120__si_class_type_infoE',
#    'address': '0xc096f1e3'},
#   {'type': 'function', 'name': '_ZNSt9bad_allocD1Ev', 'address': '0xc0950910'},
#   {'type': 'function', 'name': '_ZdaPv', 'address': '0xc094e3e0'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv116__enum_type_infoE',
#    'address': '0xc0977b80'},
#   {'type': 'function',
#    'name': '_ZNKSt11logic_error4whatEv',
#    'address': '0xc0950b70'},
#   {'type': 'function',
#    'name': '_ZN10__cxxabiv119__getExceptionClassEPK17_Unwind_Exception',
#    'address': '0xc094ead0'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv117__class_type_infoE',
#    'address': '0xc096efbe'},
#   {'type': 'function', 'name': '__cxa_get_globals', 'address': '0xc094f400'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE10__align_itILj16EEEjj',
#    'address': '0xc094de70'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk117__compressed_pairINS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE5__repES5_EC2ILb1EvEEv',
#    'address': '0xc094d540'},
#   {'type': 'function',
#    'name': '_ZnwjSt11align_val_tRKSt9nothrow_t',
#    'address': '0xc094e540'},
#   {'type': 'function',
#    'name': '__cxa_get_exception_ptr',
#    'address': '0xc094ede0'},
#   {'type': 'function', 'name': '_Znwj', 'address': '0xc094e1f0'},
#   {'type': 'variable',
#    'name': '_ZTISt14overflow_error',
#    'address': '0xc0976738'},
#   {'type': 'function', 'name': '__cxa_pure_virtual', 'address': '0xc0968f50'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorD1Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTIPKDh', 'address': '0xc09779f8'},
#   {'type': 'variable', 'name': '_ZTIPKDi', 'address': '0xc0977b10'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv120__function_type_infoE',
#    'address': '0xc096f026'},
#   {'type': 'function',
#    'name': '_ZN7_JNIEnv17GetStringUTFCharsEP8_jstringPh',
#    'address': '0xc094cee0'},
#   {'type': 'function',
#    'name': '_ZNSt11range_errorD1Ev',
#    'address': '0xc0950b80'},
#   {'type': 'function',
#    'name': '_ZNSt12out_of_rangeD1Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTSSt11logic_error', 'address': '0xc096d23e'},
#   {'type': 'variable',
#    'name': '_ZTVSt12domain_error',
#    'address': '0xc097666c'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorD2Ev',
#    'address': '0xc0950b80'},
#   {'type': 'variable',
#    'name': '_ZTISt15underflow_error',
#    'address': '0xc0976758'},
#   {'type': 'variable', 'name': '_ZTIPKDn', 'address': '0xc0977778'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv119__pointer_type_infoE',
#    'address': '0xc0977c38'},
#   {'type': 'function',
#    'name': '_ZnajSt11align_val_tRKSt9nothrow_t',
#    'address': '0xc094e5c0'},
#   {'type': 'function',
#    'name': '__cxa_decrement_exception_refcount',
#    'address': '0xc094ef40'},
#   {'type': 'variable', 'name': '_ZTISt9bad_alloc', 'address': '0xc097662c'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv116__enum_type_infoE',
#    'address': '0xc0977b64'},
#   {'type': 'function',
#    'name': '__cxa_allocate_dependent_exception',
#    'address': '0xc094ebc0'},
#   {'type': 'variable', 'name': '_ZTIPKDs', 'address': '0xc0977ae8'},
#   {'type': 'variable',
#    'name': '_ZTISt20bad_array_new_length',
#    'address': '0xc0976638'},
#   {'type': 'function', 'name': '__cxa_demangle', 'address': '0xc0951110'},
#   {'type': 'variable', 'name': '_ZTIPKDu', 'address': '0xc0977ac0'},
#   {'type': 'variable', 'name': '_ZTSPKDh', 'address': '0xc096f153'},
#   {'type': 'function',
#    'name': '_ZNKSt9exception4whatEv',
#    'address': '0xc0950950'},
#   {'type': 'variable', 'name': '_ZTSPKDi', 'address': '0xc096f19b'},
#   {'type': 'function',
#    'name': '_ZNSt16invalid_argumentD1Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'function',
#    'name': '_ZSt15get_new_handlerv',
#    'address': '0xc094f760'},
#   {'type': 'function',
#    'name': '_ZNSt15underflow_errorD2Ev',
#    'address': '0xc0950b80'},
#   {'type': 'function', 'name': '_ZNSt9bad_allocD2Ev', 'address': '0xc0950910'},
#   {'type': 'variable', 'name': '_ZTSPKDn', 'address': '0xc096f0c0'},
#   {'type': 'function', 'name': '_ZNSt8bad_castC1Ev', 'address': '0xc0968dd0'},
#   {'type': 'function',
#    'name': '_ZdlPvRKSt9nothrow_t',
#    'address': '0xc094e380'},
#   {'type': 'function',
#    'name': '__cxa_deleted_virtual',
#    'address': '0xc0968f80'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv129__pointer_to_member_type_infoE',
#    'address': '0xc09776e8'},
#   {'type': 'function',
#    'name': '_ZNSt10bad_typeidD0Ev',
#    'address': '0xc0968ef0'},
#   {'type': 'variable', 'name': '_ZTSSt11range_error', 'address': '0xc096d285'},
#   {'type': 'variable', 'name': '_ZTSPKDs', 'address': '0xc096f18f'},
#   {'type': 'variable',
#    'name': '_ZTVSt13bad_exception',
#    'address': '0xc097660c'},
#   {'type': 'variable', 'name': '_ZTSPKDu', 'address': '0xc096f183'},
#   {'type': 'variable',
#    'name': '_ZTIN10__cxxabiv117__class_type_infoE',
#    'address': '0xc09776b8'},
#   {'type': 'function',
#    'name': '_ZNKSt9bad_alloc4whatEv',
#    'address': '0xc0950a20'},
#   {'type': 'function',
#    'name': '_ZNSt20bad_array_new_lengthC1Ev',
#    'address': '0xc0950a40'},
#   {'type': 'variable', 'name': '_ZTSDh', 'address': '0xc096f14c'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorD2Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTSDi', 'address': '0xc096f194'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC1EPKc',
#    'address': '0xc094e7d0'},
#   {'type': 'function',
#    'name': '_ZNSt11range_errorD2Ev',
#    'address': '0xc0950b80'},
#   {'type': 'function',
#    'name': '_ZNSt12out_of_rangeD2Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'function',
#    'name': '__cxa_free_dependent_exception',
#    'address': '0xc094ec80'},
#   {'type': 'variable', 'name': '_ZTSDn', 'address': '0xc096f0b9'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC2ERKS_',
#    'address': '0xc094e860'},
#   {'type': 'variable',
#    'name': '_ZTSN10__cxxabiv116__shim_type_infoE',
#    'address': '0xc096ef9d'},
#   {'type': 'variable', 'name': '_ZTIPKa', 'address': '0xc0977840'},
#   {'type': 'variable',
#    'name': '_ZTISt12out_of_range',
#    'address': '0xc09766ec'},
#   {'type': 'variable', 'name': '_ZTIPKb', 'address': '0xc09777a0'},
#   {'type': 'variable', 'name': '_ZTIPKc', 'address': '0xc09777f0'},
#   {'type': 'function',
#    'name': '_ZdaPvSt11align_val_tRKSt9nothrow_t',
#    'address': '0xc094e6d0'},
#   {'type': 'variable', 'name': '_ZTIPKd', 'address': '0xc0977a48'},
#   {'type': 'variable', 'name': '_ZTSDs', 'address': '0xc096f188'},
#   {'type': 'variable', 'name': '_ZTIPKe', 'address': '0xc0977a70'},
#   {'type': 'function',
#    'name': '_ZdlPvjSt11align_val_t',
#    'address': '0xc094e670'},
#   {'type': 'function',
#    'name': '_ZNKSt13runtime_error4whatEv',
#    'address': '0xc0950c30'},
#   {'type': 'variable', 'name': '_ZTIPKf', 'address': '0xc0977a20'},
#   {'type': 'variable', 'name': '_ZTSDu', 'address': '0xc096f17c'},
#   {'type': 'variable',
#    'name': '_ZTVN10__cxxabiv117__pbase_type_infoE',
#    'address': '0xc0977c1c'},
#   {'type': 'variable', 'name': '_ZSt7nothrow', 'address': '0xc096d17f'},
#   {'type': 'variable', 'name': '_ZTIPKg', 'address': '0xc0977a98'},
#   {'type': 'function',
#    'name': '__cxa_current_primary_exception',
#    'address': '0xc094f100'},
#   {'type': 'function',
#    'name': '_ZNSt12length_errorD0Ev',
#    'address': '0xc0950d00'},
#   {'type': 'variable', 'name': '_ZTIPKh', 'address': '0xc0977818'},
#   {'type': 'variable',
#    'name': '_ZTVSt20bad_array_new_length',
#    'address': '0xc09765dc'},
#   {'type': 'variable', 'name': '_ZTISt11logic_error', 'address': '0xc0976680'},
#   {'type': 'variable', 'name': '_ZTIPKi', 'address': '0xc09778b8'},
#   {'type': 'function',
#    'name': '_ZNSt13runtime_errorC2ERKNSt6__ndk112basic_stringIcNS0_11char_traitsIcEENS0_9allocatorIcEEEE',
#    'address': '0xc094e8f0'},
#   {'type': 'variable', 'name': '_ZTIPKj', 'address': '0xc09778e0'},
#   {'type': 'function',
#    'name': '_ZNSt16invalid_argumentD2Ev',
#    'address': '0xc0950ac0'},
#   {'type': 'variable', 'name': '_ZTIPKl', 'address': '0xc0977908'},
#   {'type': 'variable', 'name': '_ZTIPa', 'address': '0xc0977830'},
#   {'type': 'variable',
#    'name': '_ZTSSt14overflow_error',
#    'address': '0xc096d2a7'},
#   {'type': 'variable', 'name': '_ZTIPKm', 'address': '0xc0977930'},
#   {'type': 'variable', 'name': '_ZTIPb', 'address': '0xc0977790'},
#   {'type': 'variable', 'name': '_ZTIPKn', 'address': '0xc09779a8'},
#   {'type': 'variable', 'name': '_ZTIPc', 'address': '0xc09777e0'},
#   {'type': 'variable', 'name': '_ZTIPKo', 'address': '0xc09779d0'},
#   {'type': 'variable', 'name': '_ZTIPd', 'address': '0xc0977a38'},
#   {'type': 'function', 'name': '_ZNSt8bad_castC2Ev', 'address': '0xc0968dd0'},
#   {'type': 'variable', 'name': '_ZTIPe', 'address': '0xc0977a60'},
#   {'type': 'variable', 'name': '_ZTIPf', 'address': '0xc0977a10'},
#   {'type': 'variable', 'name': '_ZTIPg', 'address': '0xc0977a88'},
#   {'type': 'function',
#    'name': '_ZNSt10bad_typeidD1Ev',
#    'address': '0xc0968ec0'},
#   {'type': 'function', 'name': '_Znaj', 'address': '0xc094e2d0'},
#   {'type': 'variable',
#    'name': '_ZTVSt12out_of_range',
#    'address': '0xc09766d8'},
#   {'type': 'variable', 'name': '_ZTIPKs', 'address': '0xc0977868'},
#   {'type': 'variable', 'name': '_ZTIPh', 'address': '0xc0977808'},
#   {'type': 'function',
#    'name': '_ZNSt13bad_exceptionD0Ev',
#    'address': '0xc0950970'},
#   {'type': 'variable', 'name': '_ZTIPKt', 'address': '0xc0977890'},
#   {'type': 'variable', 'name': '_ZTIPi', 'address': '0xc09778a8'},
#   {'type': 'variable', 'name': '_ZTIPj', 'address': '0xc09778d0'},
#   {'type': 'variable', 'name': '_ZTIPKv', 'address': '0xc0977750'},
#   {'type': 'variable', 'name': '_ZTIPKw', 'address': '0xc09777c8'},
#   {'type': 'variable', 'name': '_ZTIPl', 'address': '0xc09778f8'},
#   {'type': 'function',
#    'name': '_ZdlPvSt11align_val_t',
#    'address': '0xc094e610'},
#   {'type': 'variable', 'name': '_ZTIPKx', 'address': '0xc0977958'},
#   {'type': 'variable', 'name': '_ZTIPm', 'address': '0xc0977920'},
#   {'type': 'variable',
#    'name': '_ZTSSt12domain_error',
#    'address': '0xc096d22d'},
#   {'type': 'variable', 'name': '_ZTIPKy', 'address': '0xc0977980'},
#   {'type': 'variable', 'name': '_ZTIPn', 'address': '0xc0977998'},
#   {'type': 'function',
#    'name': '_ZNSt6__ndk112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEED2Ev',
#    'address': '0xc094d090'},
#   {'type': 'variable', 'name': '_ZTIPo', 'address': '0xc09779c0'},
#   {'type': 'function',
#    'name': '_ZNSt20bad_array_new_lengthC2Ev',
#    'address': '0xc0950a40'},
#   {'type': 'variable', 'name': '_ZTISt11range_error', 'address': '0xc0976718'},
#   {'type': 'variable', 'name': '_ZTIPs', 'address': '0xc0977858'},
#   {'type': 'variable', 'name': '_ZTVSt9type_info', 'address': '0xc0977c98'},
#   {'type': 'variable', 'name': '_ZTIPt', 'address': '0xc0977880'},
#   {'type': 'function', 'name': '__cxa_begin_catch', 'address': '0xc094edf0'},
#   {'type': 'variable', 'name': '_ZTIPv', 'address': '0xc0977740'},
#   {'type': 'variable', 'name': '_ZTIPw', 'address': '0xc09777b8'},
#   {'type': 'function', 'name': '_ZNSt9bad_allocC1Ev', 'address': '0xc09509c0'},
#   {'type': 'function',
#    'name': '__cxa_get_globals_fast',
#    'address': '0xc094f4b0'},
#   {'type': 'variable', 'name': '_ZTIPx', 'address': '0xc0977948'},
#   {'type': 'variable', 'name': '_ZTIPy', 'address': '0xc0977970'},
#   {'type': 'function', 'name': '_ZdaPvj', 'address': '0xc094e440'},
#   {'type': 'variable', 'name': '_ZTVSt11logic_error', 'address': '0xc0976644'},
#   {'type': 'function',
#    'name': '_ZNSt11logic_errorC1ERKNSt6__ndk112basic_stringIcNS0_11char_traitsIcEENS0_9allocatorIcEEEE',
#    'address': '0xc094e730'},
#   {'type': 'variable', 'name': '_ZTVSt9exception', 'address': '0xc09765f0'},
#   {'type': 'variable', 'name': '_ZTIPDh', 'address': '0xc09779e8'},
#   {'type': 'variable', 'name': '_ZTIPDi', 'address': '0xc0977b00'},
#   {'type': 'variable',
#    'name': '_ZTVSt13runtime_error',
#    'address': '0xc0976658'}]}
