# %%
import androguard.misc

# %%
a,d,dx = androguard.misc.AnalyzeAPK("../../androidSampleAPK/Apk Files/Tic-Tac-Toe.apk")

# %%
a.get_android_manifest_xml().items()
# Out:
# [('{http://schemas.android.com/apk/res/android}versionCode', '1'),
#  ('{http://schemas.android.com/apk/res/android}versionName', '1.0'),
#  ('package', 'com.example.user.tic_tac_toe'),
#  ('platformBuildVersionCode', '25'),
#  ('platformBuildVersionName', '7.1.1')]

# %%
a.get_activities()
# Out:
# ['com.example.user.tic_tac_toe.MainActivity']

# %%
list(dx.get_classes())
# Out:
# [<analysis.ClassAnalysis Landroid/support/annotation/AnimRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/AnimatorRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/AnyRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/AnyThread;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/ArrayRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/AttrRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/BinderThread;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/BoolRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/CallSuper;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/CheckResult;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/ColorInt;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/ColorRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/DimenRes;>,
#  <analysis.ClassAnalysis Landroid/support/annotation/Dimension;>,
# ...
