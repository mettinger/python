# %%
import androguard.misc

# %%
a,d,dx = androguard.misc.AnalyzeAPK("../../androidSampleAPK/Apk Files/Tic-Tac-Toe.apk")

# %%
a.androidversion
# Out:
# {'Code': '1', 'Name': '1.0'}

# %%
dx.strings
# Out:
# {'LIBRARY': <analysis.StringAnalysis 'LIBRARY'>,
#  'LIBRARY_GROUP': <analysis.StringAnalysis 'LIBRARY_GROUP'>,
#  'GROUP_ID': <analysis.StringAnalysis 'GROUP_ID'>,
#  'TESTS': <analysis.StringAnalysis 'TESTS'>,
#  'SUBCLASSES': <analysis.StringAnalysis 'SUBCLASSES'>,
#  'No constant state support for SDK < 24.': <analysis.StringAnalysis 'No constant state su'...>,
#  'PathParser': <analysis.StringAnalysis 'PathParser'>,
#  ' Points are coincident': <analysis.StringAnalysis ' Points are coincide'...>,
#  'Points are too far apart ': <analysis.StringAnalysis 'Points are too far a'...>,
#  'Error in parsing ': <analysis.StringAnalysis 'Error in parsing '>,
#  'error in parsing "': <analysis.StringAnalysis 'error in parsing "'>,
#  '"': <analysis.StringAnalysis '"'>,
#  'http://schemas.android.com/apk/res/android': <analysis.StringAnalysis 'http://schemas.andro'...>,
#  'Unknown object in the tree!': <analysis.StringAnalysis 'Unknown object in th'...>,
# ...
