# %%
import pandas as pd
pd.set_option('display.max_columns',None)

# %%
datafileName = '/Users/marke/Desktop/planetAlpha/data/ameriflux/AMF_US-Wrc_BASE-BADM_8-1/AMF_US-Wrc_BASE_HH_8-1.csv'
df = pd.read_csv(datafileName, header=2)
print df.shape
# Out:
# (315552, 38)

# %%
df.tail()
# Out:
#         TIMESTAMP_START  TIMESTAMP_END     USTAR        TA        WD  \
# 315547     201512312130   201512312200     0.889    -4.469   146.558
# 315548     201512312200   201512312230     1.045    -4.569   142.244
# 315549     201512312230   201512312300     0.997    -4.557   145.673
# 315550     201512312300   201512312330     0.805    -4.644   145.060
# 315551     201512312330   201601010000 -9999.000 -9999.000 -9999.000
#
#               WS  NEE_PI        FC    SC         H    SH        LE   SLE  \
# 315547     4.099   -9999    -0.906 -9999   -14.345 -9999     0.206 -9999
# 315548     4.341   -9999     0.308 -9999   -28.236 -9999    -3.405 -9999
# 315549     4.792   -9999    -0.153 -9999   -45.769 -9999    -3.069 -9999
# 315550     4.566   -9999    -0.469 -9999   -31.385 -9999    -1.209 -9999
# 315551 -9999.000   -9999 -9999.000 -9999 -9999.000 -9999 -9999.000 -9999
#
#                G      TS_1      TS_2       P        RH        PA   CO2_1  \
# ...
