# %%
# %matplotlib notebook

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
pd.set_option('display.max_columns',None)

# %%
#datafileName = '/Users/marke/Desktop/planetAlpha/data/ameriflux/AMF_US-Wrc_BASE-BADM_8-1/AMF_US-Wrc_BASE_HH_8-1.csv'
datafileName = '/Users/marke/Desktop/planetAlpha/data/ameriflux/AMF_US-Ha1_BASE-BADM_10-1/AMF_US-Ha1_BASE_HR_10-1.csv'
df = pd.read_csv(datafileName, header=2)
print df.shape
# Out:
# (219144, 38)

# %%
df.tail()
# Out:
#         TIMESTAMP_START  TIMESTAMP_END  USTAR   TA     WD   WS  NEE_PI  \
# 219139     201512311900   201512312000  0.720  2.4  275.0  2.4 -9999.0
# 219140     201512312000   201512312100  0.642  2.1  268.0  2.3 -9999.0
# 219141     201512312100   201512312200  0.486  1.8  276.0  1.8 -9999.0
# 219142     201512312200   201512312300  0.645  1.8  273.0  2.1 -9999.0
# 219143     201512312300   201601010000  0.648  1.8  276.0  2.4 -9999.0
#
#             FC      SC     H    SH        LE   SLE     G  TS_1    TS_2    P  \
# 219139     1.3 -9999.0 -49.4 -9999    17.794 -9999 -9999   3.8 -9999.0  0.0
# 219140     1.4 -9999.0 -43.5 -9999    12.863 -9999 -9999   3.8 -9999.0  0.0
# 219141     1.5 -9999.0 -32.1 -9999    10.746 -9999 -9999   3.8 -9999.0  0.0
# 219142 -9999.0 -9999.0 -34.7 -9999 -9999.000 -9999 -9999   3.8 -9999.0  0.0
# 219143     2.7 -9999.0 -37.1 -9999    19.840 -9999 -9999   3.8 -9999.0  0.0
#
#           RH      PA  CO2_1  CO2_2  VPD_PI  SWC_1  SWC_2  NETRAD  PPFD_IN  \
# ...

# %%
plt.plot([i for i in df['CO2_1'].values if i !=-9999.])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df1 = df[df['CO2_1'] != -9999.0]
len(df1), len(df)
# Out:
# (131134, 219144)

# %%
df1.plot('TIMESTAMP_START','CO2_1','scatter')
# Out:
# <img src="data:image/png;base64,..." width="900">
