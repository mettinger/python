# %%
class Category:
    def __init__(self, src:dict, target:dict, comp:dict, addIdentities:bool = False) -> None:
        self.src = src
        self.target = target
        self.comp = comp
        self.objects = set(src.values()).union(set(target.values()))
        self.morphisms = list(src.keys())

        assert src.keys() == target.keys()
        assert self.composabilityCheck()
        assert self.compositionCheck()
        assert self.associativityCheck()

        if addIdentities:
            self.addIdentities()
        
    def __str__(self) -> str:
        return str((self.src, self.target, self.comp))

    def composabilityCheck(self)-> bool:
        return True
    
    def compositionCheck(self) -> bool:
        return True
    
    def associativityCheck(self) -> bool:
        return True
    
    def addIdentities(self) -> None:
        for thisObject in self.objects:
            thisMorphism = "id_" + str(thisObject)
            self.src[thisMorphism] = thisObject
            self.target[thisMorphism] = thisObject
            self.morphisms = self.morphisms + [thisMorphism]
            for i in self.morphisms:
                if self.src[i] == thisObject:
                    self.comp[(i, thisMorphism)] = i
                if self.target[i] == thisObject:
                    self.comp[(thisMorphism, i)] = i


class Functor:
    def __init__(self, srcCat: Category, targetCat: Category, objectMap: dict, morphismMap: dict) -> None:
        self.srcCat = srcCat
        self.targetCat = targetCat
        self.objectMap = objectMap
        self.morphismMap = morphismMap

        assert self.homomorphismFunctorCheck()

    def homomorphismFunctorCheck(self) -> bool:
        return True

# %%
def productCategory(c:Category, d:Category):
    src = srcProduct(c, d)
    target = targetProduct(c, d)
    comp = compProduct(c,d)
    productCat = Category(src, target, comp, addIdentities=False)
    return productCat

def srcProduct(c:Category, d:Category):
    src = {(m1,m2):(o1, o2) for m1, o1 in c.src.items() for m2,o2 in d.src.items()}
    return src

def targetProduct(c:Category, d:Category):
    target = {(m1,m2):(o1, o2) for m1, o1 in c.target.items() for m2,o2 in d.target.items()}
    return target
    
def compProduct(c:Category, d:Category):
    comp = {((m1Source[0],m2Source[0]), (m1Source[1],m2Source[1])):(m1Target, m2Target) for m1Source, m1Target in c.comp.items() for m2Source, m2Target in d.comp.items()}
    return comp

# %%
src = {"f":0, "g":1, "h":2, "i":0, "m":0, "k":1}
target = {"f":1, "g":2, "h":3, "i":2, "m":3, "k":3}
comp = {("g","f"): "i", ("h", "g"):"k", ("h","i"): "m", ("k","f"): "m"}

c1 = Category(src, target, comp, True)
c2 = Category(src, target, comp, True)

productC1C2 = productCategory(c1, c2)

# %%
productC1C2.comp
# Out:
# {(('g', 'g'), ('f', 'f')): ('i', 'i'),
#  (('g', 'h'), ('f', 'g')): ('i', 'k'),
#  (('g', 'h'), ('f', 'i')): ('i', 'm'),
#  (('g', 'k'), ('f', 'f')): ('i', 'm'),
#  (('g', 'f'), ('f', 'id_0')): ('i', 'f'),
#  (('g', 'i'), ('f', 'id_0')): ('i', 'i'),
#  (('g', 'm'), ('f', 'id_0')): ('i', 'm'),
#  (('g', 'id_0'), ('f', 'id_0')): ('i', 'id_0'),
#  (('g', 'id_1'), ('f', 'f')): ('i', 'f'),
#  (('g', 'g'), ('f', 'id_1')): ('i', 'g'),
#  (('g', 'k'), ('f', 'id_1')): ('i', 'k'),
#  (('g', 'id_1'), ('f', 'id_1')): ('i', 'id_1'),
#  (('g', 'id_2'), ('f', 'g')): ('i', 'g'),
#  (('g', 'h'), ('f', 'id_2')): ('i', 'h'),
#  (('g', 'id_2'), ('f', 'i')): ('i', 'i'),
#  (('g', 'id_2'), ('f', 'id_2')): ('i', 'id_2'),
#  (('g', 'id_3'), ('f', 'h')): ('i', 'h'),
#  (('g', 'id_3'), ('f', 'm')): ('i', 'm'),
#  (('g', 'id_3'), ('f', 'k')): ('i', 'k'),
#  (('g', 'id_3'), ('f', 'id_3')): ('i', 'id_3'),
#  (('h', 'g'), ('g', 'f')): ('k', 'i'),
#  (('h', 'h'), ('g', 'g')): ('k', 'k'),
#  (('h', 'h'), ('g', 'i')): ('k', 'm'),
#  (('h', 'k'), ('g', 'f')): ('k', 'm'),
#  (('h', 'f'), ('g', 'id_0')): ('k', 'f'),
#  (('h', 'i'), ('g', 'id_0')): ('k', 'i'),
#  (('h', 'm'), ('g', 'id_0')): ('k', 'm'),
#  (('h', 'id_0'), ('g', 'id_0')): ('k', 'id_0'),
#  (('h', 'id_1'), ('g', 'f')): ('k', 'f'),
#  (('h', 'g'), ('g', 'id_1')): ('k', 'g'),
#  (('h', 'k'), ('g', 'id_1')): ('k', 'k'),
#  (('h', 'id_1'), ('g', 'id_1')): ('k', 'id_1'),
#  (('h', 'id_2'), ('g', 'g')): ('k', 'g'),
#  (('h', 'h'), ('g', 'id_2')): ('k', 'h'),
#  (('h', 'id_2'), ('g', 'i')): ('k', 'i'),
#  (('h', 'id_2'), ('g', 'id_2')): ('k', 'id_2'),
#  (('h', 'id_3'), ('g', 'h')): ('k', 'h'),
#  (('h', 'id_3'), ('g', 'm')): ('k', 'm'),
#  (('h', 'id_3'), ('g', 'k')): ('k', 'k'),
#  (('h', 'id_3'), ('g', 'id_3')): ('k', 'id_3'),
#  (('h', 'g'), ('i', 'f')): ('m', 'i'),
#  (('h', 'h'), ('i', 'g')): ('m', 'k'),
#  (('h', 'h'), ('i', 'i')): ('m', 'm'),
#  (('h', 'k'), ('i', 'f')): ('m', 'm'),
#  (('h', 'f'), ('i', 'id_0')): ('m', 'f'),
#  (('h', 'i'), ('i', 'id_0')): ('m', 'i'),
#  (('h', 'm'), ('i', 'id_0')): ('m', 'm'),
#  (('h', 'id_0'), ('i', 'id_0')): ('m', 'id_0'),
#  (('h', 'id_1'), ('i', 'f')): ('m', 'f'),
#  (('h', 'g'), ('i', 'id_1')): ('m', 'g'),
#  (('h', 'k'), ('i', 'id_1')): ('m', 'k'),
#  (('h', 'id_1'), ('i', 'id_1')): ('m', 'id_1'),
#  (('h', 'id_2'), ('i', 'g')): ('m', 'g'),
#  (('h', 'h'), ('i', 'id_2')): ('m', 'h'),
#  (('h', 'id_2'), ('i', 'i')): ('m', 'i'),
#  (('h', 'id_2'), ('i', 'id_2')): ('m', 'id_2'),
#  (('h', 'id_3'), ('i', 'h')): ('m', 'h'),
#  (('h', 'id_3'), ('i', 'm')): ('m', 'm'),
#  (('h', 'id_3'), ('i', 'k')): ('m', 'k'),
#  (('h', 'id_3'), ('i', 'id_3')): ('m', 'id_3'),
#  (('k', 'g'), ('f', 'f')): ('m', 'i'),
#  (('k', 'h'), ('f', 'g')): ('m', 'k'),
#  (('k', 'h'), ('f', 'i')): ('m', 'm'),
#  (('k', 'k'), ('f', 'f')): ('m', 'm'),
#  (('k', 'f'), ('f', 'id_0')): ('m', 'f'),
#  (('k', 'i'), ('f', 'id_0')): ('m', 'i'),
#  (('k', 'm'), ('f', 'id_0')): ('m', 'm'),
#  (('k', 'id_0'), ('f', 'id_0')): ('m', 'id_0'),
#  (('k', 'id_1'), ('f', 'f')): ('m', 'f'),
#  (('k', 'g'), ('f', 'id_1')): ('m', 'g'),
#  (('k', 'k'), ('f', 'id_1')): ('m', 'k'),
#  (('k', 'id_1'), ('f', 'id_1')): ('m', 'id_1'),
#  (('k', 'id_2'), ('f', 'g')): ('m', 'g'),
#  (('k', 'h'), ('f', 'id_2')): ('m', 'h'),
#  (('k', 'id_2'), ('f', 'i')): ('m', 'i'),
#  (('k', 'id_2'), ('f', 'id_2')): ('m', 'id_2'),
#  (('k', 'id_3'), ('f', 'h')): ('m', 'h'),
#  (('k', 'id_3'), ('f', 'm')): ('m', 'm'),
#  (('k', 'id_3'), ('f', 'k')): ('m', 'k'),
#  (('k', 'id_3'), ('f', 'id_3')): ('m', 'id_3'),
#  (('f', 'g'), ('id_0', 'f')): ('f', 'i'),
#  (('f', 'h'), ('id_0', 'g')): ('f', 'k'),
#  (('f', 'h'), ('id_0', 'i')): ('f', 'm'),
#  (('f', 'k'), ('id_0', 'f')): ('f', 'm'),
#  (('f', 'f'), ('id_0', 'id_0')): ('f', 'f'),
#  (('f', 'i'), ('id_0', 'id_0')): ('f', 'i'),
#  (('f', 'm'), ('id_0', 'id_0')): ('f', 'm'),
#  (('f', 'id_0'), ('id_0', 'id_0')): ('f', 'id_0'),
#  (('f', 'id_1'), ('id_0', 'f')): ('f', 'f'),
#  (('f', 'g'), ('id_0', 'id_1')): ('f', 'g'),
#  (('f', 'k'), ('id_0', 'id_1')): ('f', 'k'),
#  (('f', 'id_1'), ('id_0', 'id_1')): ('f', 'id_1'),
#  (('f', 'id_2'), ('id_0', 'g')): ('f', 'g'),
#  (('f', 'h'), ('id_0', 'id_2')): ('f', 'h'),
#  (('f', 'id_2'), ('id_0', 'i')): ('f', 'i'),
#  (('f', 'id_2'), ('id_0', 'id_2')): ('f', 'id_2'),
#  (('f', 'id_3'), ('id_0', 'h')): ('f', 'h'),
#  (('f', 'id_3'), ('id_0', 'm')): ('f', 'm'),
#  (('f', 'id_3'), ('id_0', 'k')): ('f', 'k'),
#  (('f', 'id_3'), ('id_0', 'id_3')): ('f', 'id_3'),
#  (('i', 'g'), ('id_0', 'f')): ('i', 'i'),
#  (('i', 'h'), ('id_0', 'g')): ('i', 'k'),
#  (('i', 'h'), ('id_0', 'i')): ('i', 'm'),
#  (('i', 'k'), ('id_0', 'f')): ('i', 'm'),
#  (('i', 'f'), ('id_0', 'id_0')): ('i', 'f'),
#  (('i', 'i'), ('id_0', 'id_0')): ('i', 'i'),
#  (('i', 'm'), ('id_0', 'id_0')): ('i', 'm'),
#  (('i', 'id_0'), ('id_0', 'id_0')): ('i', 'id_0'),
#  (('i', 'id_1'), ('id_0', 'f')): ('i', 'f'),
#  (('i', 'g'), ('id_0', 'id_1')): ('i', 'g'),
#  (('i', 'k'), ('id_0', 'id_1')): ('i', 'k'),
#  (('i', 'id_1'), ('id_0', 'id_1')): ('i', 'id_1'),
#  (('i', 'id_2'), ('id_0', 'g')): ('i', 'g'),
#  (('i', 'h'), ('id_0', 'id_2')): ('i', 'h'),
#  (('i', 'id_2'), ('id_0', 'i')): ('i', 'i'),
#  (('i', 'id_2'), ('id_0', 'id_2')): ('i', 'id_2'),
#  (('i', 'id_3'), ('id_0', 'h')): ('i', 'h'),
#  (('i', 'id_3'), ('id_0', 'm')): ('i', 'm'),
#  (('i', 'id_3'), ('id_0', 'k')): ('i', 'k'),
#  (('i', 'id_3'), ('id_0', 'id_3')): ('i', 'id_3'),
#  (('m', 'g'), ('id_0', 'f')): ('m', 'i'),
#  (('m', 'h'), ('id_0', 'g')): ('m', 'k'),
#  (('m', 'h'), ('id_0', 'i')): ('m', 'm'),
#  (('m', 'k'), ('id_0', 'f')): ('m', 'm'),
#  (('m', 'f'), ('id_0', 'id_0')): ('m', 'f'),
#  (('m', 'i'), ('id_0', 'id_0')): ('m', 'i'),
#  (('m', 'm'), ('id_0', 'id_0')): ('m', 'm'),
#  (('m', 'id_0'), ('id_0', 'id_0')): ('m', 'id_0'),
#  (('m', 'id_1'), ('id_0', 'f')): ('m', 'f'),
#  (('m', 'g'), ('id_0', 'id_1')): ('m', 'g'),
#  (('m', 'k'), ('id_0', 'id_1')): ('m', 'k'),
#  (('m', 'id_1'), ('id_0', 'id_1')): ('m', 'id_1'),
#  (('m', 'id_2'), ('id_0', 'g')): ('m', 'g'),
#  (('m', 'h'), ('id_0', 'id_2')): ('m', 'h'),
#  (('m', 'id_2'), ('id_0', 'i')): ('m', 'i'),
#  (('m', 'id_2'), ('id_0', 'id_2')): ('m', 'id_2'),
#  (('m', 'id_3'), ('id_0', 'h')): ('m', 'h'),
#  (('m', 'id_3'), ('id_0', 'm')): ('m', 'm'),
#  (('m', 'id_3'), ('id_0', 'k')): ('m', 'k'),
#  (('m', 'id_3'), ('id_0', 'id_3')): ('m', 'id_3'),
#  (('id_0', 'g'), ('id_0', 'f')): ('id_0', 'i'),
#  (('id_0', 'h'), ('id_0', 'g')): ('id_0', 'k'),
#  (('id_0', 'h'), ('id_0', 'i')): ('id_0', 'm'),
#  (('id_0', 'k'), ('id_0', 'f')): ('id_0', 'm'),
#  (('id_0', 'f'), ('id_0', 'id_0')): ('id_0', 'f'),
#  (('id_0', 'i'), ('id_0', 'id_0')): ('id_0', 'i'),
#  (('id_0', 'm'), ('id_0', 'id_0')): ('id_0', 'm'),
#  (('id_0', 'id_0'), ('id_0', 'id_0')): ('id_0', 'id_0'),
#  (('id_0', 'id_1'), ('id_0', 'f')): ('id_0', 'f'),
#  (('id_0', 'g'), ('id_0', 'id_1')): ('id_0', 'g'),
#  (('id_0', 'k'), ('id_0', 'id_1')): ('id_0', 'k'),
#  (('id_0', 'id_1'), ('id_0', 'id_1')): ('id_0', 'id_1'),
#  (('id_0', 'id_2'), ('id_0', 'g')): ('id_0', 'g'),
#  (('id_0', 'h'), ('id_0', 'id_2')): ('id_0', 'h'),
#  (('id_0', 'id_2'), ('id_0', 'i')): ('id_0', 'i'),
#  (('id_0', 'id_2'), ('id_0', 'id_2')): ('id_0', 'id_2'),
#  (('id_0', 'id_3'), ('id_0', 'h')): ('id_0', 'h'),
#  (('id_0', 'id_3'), ('id_0', 'm')): ('id_0', 'm'),
#  (('id_0', 'id_3'), ('id_0', 'k')): ('id_0', 'k'),
#  (('id_0', 'id_3'), ('id_0', 'id_3')): ('id_0', 'id_3'),
#  (('id_1', 'g'), ('f', 'f')): ('f', 'i'),
#  (('id_1', 'h'), ('f', 'g')): ('f', 'k'),
#  (('id_1', 'h'), ('f', 'i')): ('f', 'm'),
#  (('id_1', 'k'), ('f', 'f')): ('f', 'm'),
#  (('id_1', 'f'), ('f', 'id_0')): ('f', 'f'),
#  (('id_1', 'i'), ('f', 'id_0')): ('f', 'i'),
#  (('id_1', 'm'), ('f', 'id_0')): ('f', 'm'),
#  (('id_1', 'id_0'), ('f', 'id_0')): ('f', 'id_0'),
#  (('id_1', 'id_1'), ('f', 'f')): ('f', 'f'),
#  (('id_1', 'g'), ('f', 'id_1')): ('f', 'g'),
#  (('id_1', 'k'), ('f', 'id_1')): ('f', 'k'),
#  (('id_1', 'id_1'), ('f', 'id_1')): ('f', 'id_1'),
#  (('id_1', 'id_2'), ('f', 'g')): ('f', 'g'),
#  (('id_1', 'h'), ('f', 'id_2')): ('f', 'h'),
#  (('id_1', 'id_2'), ('f', 'i')): ('f', 'i'),
#  (('id_1', 'id_2'), ('f', 'id_2')): ('f', 'id_2'),
#  (('id_1', 'id_3'), ('f', 'h')): ('f', 'h'),
#  (('id_1', 'id_3'), ('f', 'm')): ('f', 'm'),
#  (('id_1', 'id_3'), ('f', 'k')): ('f', 'k'),
#  (('id_1', 'id_3'), ('f', 'id_3')): ('f', 'id_3'),
#  (('g', 'g'), ('id_1', 'f')): ('g', 'i'),
#  (('g', 'h'), ('id_1', 'g')): ('g', 'k'),
#  (('g', 'h'), ('id_1', 'i')): ('g', 'm'),
#  (('g', 'k'), ('id_1', 'f')): ('g', 'm'),
#  (('g', 'f'), ('id_1', 'id_0')): ('g', 'f'),
#  (('g', 'i'), ('id_1', 'id_0')): ('g', 'i'),
#  (('g', 'm'), ('id_1', 'id_0')): ('g', 'm'),
#  (('g', 'id_0'), ('id_1', 'id_0')): ('g', 'id_0'),
#  (('g', 'id_1'), ('id_1', 'f')): ('g', 'f'),
#  (('g', 'g'), ('id_1', 'id_1')): ('g', 'g'),
#  (('g', 'k'), ('id_1', 'id_1')): ('g', 'k'),
#  (('g', 'id_1'), ('id_1', 'id_1')): ('g', 'id_1'),
#  (('g', 'id_2'), ('id_1', 'g')): ('g', 'g'),
#  (('g', 'h'), ('id_1', 'id_2')): ('g', 'h'),
#  (('g', 'id_2'), ('id_1', 'i')): ('g', 'i'),
#  (('g', 'id_2'), ('id_1', 'id_2')): ('g', 'id_2'),
#  (('g', 'id_3'), ('id_1', 'h')): ('g', 'h'),
#  (('g', 'id_3'), ('id_1', 'm')): ('g', 'm'),
#  (('g', 'id_3'), ('id_1', 'k')): ('g', 'k'),
#  (('g', 'id_3'), ('id_1', 'id_3')): ('g', 'id_3'),
#  (('k', 'g'), ('id_1', 'f')): ('k', 'i'),
#  (('k', 'h'), ('id_1', 'g')): ('k', 'k'),
#  (('k', 'h'), ('id_1', 'i')): ('k', 'm'),
#  (('k', 'k'), ('id_1', 'f')): ('k', 'm'),
#  (('k', 'f'), ('id_1', 'id_0')): ('k', 'f'),
#  (('k', 'i'), ('id_1', 'id_0')): ('k', 'i'),
#  (('k', 'm'), ('id_1', 'id_0')): ('k', 'm'),
#  (('k', 'id_0'), ('id_1', 'id_0')): ('k', 'id_0'),
#  (('k', 'id_1'), ('id_1', 'f')): ('k', 'f'),
#  (('k', 'g'), ('id_1', 'id_1')): ('k', 'g'),
#  (('k', 'k'), ('id_1', 'id_1')): ('k', 'k'),
#  (('k', 'id_1'), ('id_1', 'id_1')): ('k', 'id_1'),
#  (('k', 'id_2'), ('id_1', 'g')): ('k', 'g'),
#  (('k', 'h'), ('id_1', 'id_2')): ('k', 'h'),
#  (('k', 'id_2'), ('id_1', 'i')): ('k', 'i'),
#  (('k', 'id_2'), ('id_1', 'id_2')): ('k', 'id_2'),
#  (('k', 'id_3'), ('id_1', 'h')): ('k', 'h'),
#  (('k', 'id_3'), ('id_1', 'm')): ('k', 'm'),
#  (('k', 'id_3'), ('id_1', 'k')): ('k', 'k'),
#  (('k', 'id_3'), ('id_1', 'id_3')): ('k', 'id_3'),
#  (('id_1', 'g'), ('id_1', 'f')): ('id_1', 'i'),
#  (('id_1', 'h'), ('id_1', 'g')): ('id_1', 'k'),
#  (('id_1', 'h'), ('id_1', 'i')): ('id_1', 'm'),
#  (('id_1', 'k'), ('id_1', 'f')): ('id_1', 'm'),
#  (('id_1', 'f'), ('id_1', 'id_0')): ('id_1', 'f'),
#  (('id_1', 'i'), ('id_1', 'id_0')): ('id_1', 'i'),
#  (('id_1', 'm'), ('id_1', 'id_0')): ('id_1', 'm'),
#  (('id_1', 'id_0'), ('id_1', 'id_0')): ('id_1', 'id_0'),
#  (('id_1', 'id_1'), ('id_1', 'f')): ('id_1', 'f'),
#  (('id_1', 'g'), ('id_1', 'id_1')): ('id_1', 'g'),
#  (('id_1', 'k'), ('id_1', 'id_1')): ('id_1', 'k'),
#  (('id_1', 'id_1'), ('id_1', 'id_1')): ('id_1', 'id_1'),
#  (('id_1', 'id_2'), ('id_1', 'g')): ('id_1', 'g'),
#  (('id_1', 'h'), ('id_1', 'id_2')): ('id_1', 'h'),
#  (('id_1', 'id_2'), ('id_1', 'i')): ('id_1', 'i'),
#  (('id_1', 'id_2'), ('id_1', 'id_2')): ('id_1', 'id_2'),
#  (('id_1', 'id_3'), ('id_1', 'h')): ('id_1', 'h'),
#  (('id_1', 'id_3'), ('id_1', 'm')): ('id_1', 'm'),
#  (('id_1', 'id_3'), ('id_1', 'k')): ('id_1', 'k'),
#  (('id_1', 'id_3'), ('id_1', 'id_3')): ('id_1', 'id_3'),
#  (('id_2', 'g'), ('g', 'f')): ('g', 'i'),
#  (('id_2', 'h'), ('g', 'g')): ('g', 'k'),
#  (('id_2', 'h'), ('g', 'i')): ('g', 'm'),
#  (('id_2', 'k'), ('g', 'f')): ('g', 'm'),
#  (('id_2', 'f'), ('g', 'id_0')): ('g', 'f'),
#  (('id_2', 'i'), ('g', 'id_0')): ('g', 'i'),
#  (('id_2', 'm'), ('g', 'id_0')): ('g', 'm'),
#  (('id_2', 'id_0'), ('g', 'id_0')): ('g', 'id_0'),
#  (('id_2', 'id_1'), ('g', 'f')): ('g', 'f'),
#  (('id_2', 'g'), ('g', 'id_1')): ('g', 'g'),
#  (('id_2', 'k'), ('g', 'id_1')): ('g', 'k'),
#  (('id_2', 'id_1'), ('g', 'id_1')): ('g', 'id_1'),
#  (('id_2', 'id_2'), ('g', 'g')): ('g', 'g'),
#  (('id_2', 'h'), ('g', 'id_2')): ('g', 'h'),
#  (('id_2', 'id_2'), ('g', 'i')): ('g', 'i'),
#  (('id_2', 'id_2'), ('g', 'id_2')): ('g', 'id_2'),
#  (('id_2', 'id_3'), ('g', 'h')): ('g', 'h'),
#  (('id_2', 'id_3'), ('g', 'm')): ('g', 'm'),
#  (('id_2', 'id_3'), ('g', 'k')): ('g', 'k'),
#  (('id_2', 'id_3'), ('g', 'id_3')): ('g', 'id_3'),
#  (('h', 'g'), ('id_2', 'f')): ('h', 'i'),
#  (('h', 'h'), ('id_2', 'g')): ('h', 'k'),
#  (('h', 'h'), ('id_2', 'i')): ('h', 'm'),
#  (('h', 'k'), ('id_2', 'f')): ('h', 'm'),
#  (('h', 'f'), ('id_2', 'id_0')): ('h', 'f'),
#  (('h', 'i'), ('id_2', 'id_0')): ('h', 'i'),
#  (('h', 'm'), ('id_2', 'id_0')): ('h', 'm'),
#  (('h', 'id_0'), ('id_2', 'id_0')): ('h', 'id_0'),
#  (('h', 'id_1'), ('id_2', 'f')): ('h', 'f'),
#  (('h', 'g'), ('id_2', 'id_1')): ('h', 'g'),
#  (('h', 'k'), ('id_2', 'id_1')): ('h', 'k'),
#  (('h', 'id_1'), ('id_2', 'id_1')): ('h', 'id_1'),
#  (('h', 'id_2'), ('id_2', 'g')): ('h', 'g'),
#  (('h', 'h'), ('id_2', 'id_2')): ('h', 'h'),
#  (('h', 'id_2'), ('id_2', 'i')): ('h', 'i'),
#  (('h', 'id_2'), ('id_2', 'id_2')): ('h', 'id_2'),
#  (('h', 'id_3'), ('id_2', 'h')): ('h', 'h'),
#  (('h', 'id_3'), ('id_2', 'm')): ('h', 'm'),
#  (('h', 'id_3'), ('id_2', 'k')): ('h', 'k'),
#  (('h', 'id_3'), ('id_2', 'id_3')): ('h', 'id_3'),
#  (('id_2', 'g'), ('i', 'f')): ('i', 'i'),
#  (('id_2', 'h'), ('i', 'g')): ('i', 'k'),
#  (('id_2', 'h'), ('i', 'i')): ('i', 'm'),
#  (('id_2', 'k'), ('i', 'f')): ('i', 'm'),
#  (('id_2', 'f'), ('i', 'id_0')): ('i', 'f'),
#  (('id_2', 'i'), ('i', 'id_0')): ('i', 'i'),
#  (('id_2', 'm'), ('i', 'id_0')): ('i', 'm'),
#  (('id_2', 'id_0'), ('i', 'id_0')): ('i', 'id_0'),
#  (('id_2', 'id_1'), ('i', 'f')): ('i', 'f'),
#  (('id_2', 'g'), ('i', 'id_1')): ('i', 'g'),
#  (('id_2', 'k'), ('i', 'id_1')): ('i', 'k'),
#  (('id_2', 'id_1'), ('i', 'id_1')): ('i', 'id_1'),
#  (('id_2', 'id_2'), ('i', 'g')): ('i', 'g'),
#  (('id_2', 'h'), ('i', 'id_2')): ('i', 'h'),
#  (('id_2', 'id_2'), ('i', 'i')): ('i', 'i'),
#  (('id_2', 'id_2'), ('i', 'id_2')): ('i', 'id_2'),
#  (('id_2', 'id_3'), ('i', 'h')): ('i', 'h'),
#  (('id_2', 'id_3'), ('i', 'm')): ('i', 'm'),
#  (('id_2', 'id_3'), ('i', 'k')): ('i', 'k'),
#  (('id_2', 'id_3'), ('i', 'id_3')): ('i', 'id_3'),
#  (('id_2', 'g'), ('id_2', 'f')): ('id_2', 'i'),
#  (('id_2', 'h'), ('id_2', 'g')): ('id_2', 'k'),
#  (('id_2', 'h'), ('id_2', 'i')): ('id_2', 'm'),
#  (('id_2', 'k'), ('id_2', 'f')): ('id_2', 'm'),
#  (('id_2', 'f'), ('id_2', 'id_0')): ('id_2', 'f'),
#  (('id_2', 'i'), ('id_2', 'id_0')): ('id_2', 'i'),
#  (('id_2', 'm'), ('id_2', 'id_0')): ('id_2', 'm'),
#  (('id_2', 'id_0'), ('id_2', 'id_0')): ('id_2', 'id_0'),
#  (('id_2', 'id_1'), ('id_2', 'f')): ('id_2', 'f'),
#  (('id_2', 'g'), ('id_2', 'id_1')): ('id_2', 'g'),
#  (('id_2', 'k'), ('id_2', 'id_1')): ('id_2', 'k'),
#  (('id_2', 'id_1'), ('id_2', 'id_1')): ('id_2', 'id_1'),
#  (('id_2', 'id_2'), ('id_2', 'g')): ('id_2', 'g'),
#  (('id_2', 'h'), ('id_2', 'id_2')): ('id_2', 'h'),
#  (('id_2', 'id_2'), ('id_2', 'i')): ('id_2', 'i'),
#  (('id_2', 'id_2'), ('id_2', 'id_2')): ('id_2', 'id_2'),
#  (('id_2', 'id_3'), ('id_2', 'h')): ('id_2', 'h'),
#  (('id_2', 'id_3'), ('id_2', 'm')): ('id_2', 'm'),
#  (('id_2', 'id_3'), ('id_2', 'k')): ('id_2', 'k'),
#  (('id_2', 'id_3'), ('id_2', 'id_3')): ('id_2', 'id_3'),
#  (('id_3', 'g'), ('h', 'f')): ('h', 'i'),
#  (('id_3', 'h'), ('h', 'g')): ('h', 'k'),
#  (('id_3', 'h'), ('h', 'i')): ('h', 'm'),
#  (('id_3', 'k'), ('h', 'f')): ('h', 'm'),
#  (('id_3', 'f'), ('h', 'id_0')): ('h', 'f'),
#  (('id_3', 'i'), ('h', 'id_0')): ('h', 'i'),
#  (('id_3', 'm'), ('h', 'id_0')): ('h', 'm'),
#  (('id_3', 'id_0'), ('h', 'id_0')): ('h', 'id_0'),
#  (('id_3', 'id_1'), ('h', 'f')): ('h', 'f'),
#  (('id_3', 'g'), ('h', 'id_1')): ('h', 'g'),
#  (('id_3', 'k'), ('h', 'id_1')): ('h', 'k'),
#  (('id_3', 'id_1'), ('h', 'id_1')): ('h', 'id_1'),
#  (('id_3', 'id_2'), ('h', 'g')): ('h', 'g'),
#  (('id_3', 'h'), ('h', 'id_2')): ('h', 'h'),
#  (('id_3', 'id_2'), ('h', 'i')): ('h', 'i'),
#  (('id_3', 'id_2'), ('h', 'id_2')): ('h', 'id_2'),
#  (('id_3', 'id_3'), ('h', 'h')): ('h', 'h'),
#  (('id_3', 'id_3'), ('h', 'm')): ('h', 'm'),
#  (('id_3', 'id_3'), ('h', 'k')): ('h', 'k'),
#  (('id_3', 'id_3'), ('h', 'id_3')): ('h', 'id_3'),
#  (('id_3', 'g'), ('m', 'f')): ('m', 'i'),
#  (('id_3', 'h'), ('m', 'g')): ('m', 'k'),
#  (('id_3', 'h'), ('m', 'i')): ('m', 'm'),
#  (('id_3', 'k'), ('m', 'f')): ('m', 'm'),
#  (('id_3', 'f'), ('m', 'id_0')): ('m', 'f'),
#  (('id_3', 'i'), ('m', 'id_0')): ('m', 'i'),
#  (('id_3', 'm'), ('m', 'id_0')): ('m', 'm'),
#  (('id_3', 'id_0'), ('m', 'id_0')): ('m', 'id_0'),
#  (('id_3', 'id_1'), ('m', 'f')): ('m', 'f'),
#  (('id_3', 'g'), ('m', 'id_1')): ('m', 'g'),
#  (('id_3', 'k'), ('m', 'id_1')): ('m', 'k'),
#  (('id_3', 'id_1'), ('m', 'id_1')): ('m', 'id_1'),
#  (('id_3', 'id_2'), ('m', 'g')): ('m', 'g'),
#  (('id_3', 'h'), ('m', 'id_2')): ('m', 'h'),
#  (('id_3', 'id_2'), ('m', 'i')): ('m', 'i'),
#  (('id_3', 'id_2'), ('m', 'id_2')): ('m', 'id_2'),
#  (('id_3', 'id_3'), ('m', 'h')): ('m', 'h'),
#  (('id_3', 'id_3'), ('m', 'm')): ('m', 'm'),
#  (('id_3', 'id_3'), ('m', 'k')): ('m', 'k'),
#  (('id_3', 'id_3'), ('m', 'id_3')): ('m', 'id_3'),
#  (('id_3', 'g'), ('k', 'f')): ('k', 'i'),
#  (('id_3', 'h'), ('k', 'g')): ('k', 'k'),
#  (('id_3', 'h'), ('k', 'i')): ('k', 'm'),
#  (('id_3', 'k'), ('k', 'f')): ('k', 'm'),
#  (('id_3', 'f'), ('k', 'id_0')): ('k', 'f'),
#  (('id_3', 'i'), ('k', 'id_0')): ('k', 'i'),
#  (('id_3', 'm'), ('k', 'id_0')): ('k', 'm'),
#  (('id_3', 'id_0'), ('k', 'id_0')): ('k', 'id_0'),
#  (('id_3', 'id_1'), ('k', 'f')): ('k', 'f'),
#  (('id_3', 'g'), ('k', 'id_1')): ('k', 'g'),
#  (('id_3', 'k'), ('k', 'id_1')): ('k', 'k'),
#  (('id_3', 'id_1'), ('k', 'id_1')): ('k', 'id_1'),
#  (('id_3', 'id_2'), ('k', 'g')): ('k', 'g'),
#  (('id_3', 'h'), ('k', 'id_2')): ('k', 'h'),
#  (('id_3', 'id_2'), ('k', 'i')): ('k', 'i'),
#  (('id_3', 'id_2'), ('k', 'id_2')): ('k', 'id_2'),
#  (('id_3', 'id_3'), ('k', 'h')): ('k', 'h'),
#  (('id_3', 'id_3'), ('k', 'm')): ('k', 'm'),
#  (('id_3', 'id_3'), ('k', 'k')): ('k', 'k'),
#  (('id_3', 'id_3'), ('k', 'id_3')): ('k', 'id_3'),
#  (('id_3', 'g'), ('id_3', 'f')): ('id_3', 'i'),
#  (('id_3', 'h'), ('id_3', 'g')): ('id_3', 'k'),
#  (('id_3', 'h'), ('id_3', 'i')): ('id_3', 'm'),
#  (('id_3', 'k'), ('id_3', 'f')): ('id_3', 'm'),
#  (('id_3', 'f'), ('id_3', 'id_0')): ('id_3', 'f'),
#  (('id_3', 'i'), ('id_3', 'id_0')): ('id_3', 'i'),
#  (('id_3', 'm'), ('id_3', 'id_0')): ('id_3', 'm'),
#  (('id_3', 'id_0'), ('id_3', 'id_0')): ('id_3', 'id_0'),
#  (('id_3', 'id_1'), ('id_3', 'f')): ('id_3', 'f'),
#  (('id_3', 'g'), ('id_3', 'id_1')): ('id_3', 'g'),
#  (('id_3', 'k'), ('id_3', 'id_1')): ('id_3', 'k'),
#  (('id_3', 'id_1'), ('id_3', 'id_1')): ('id_3', 'id_1'),
#  (('id_3', 'id_2'), ('id_3', 'g')): ('id_3', 'g'),
#  (('id_3', 'h'), ('id_3', 'id_2')): ('id_3', 'h'),
#  (('id_3', 'id_2'), ('id_3', 'i')): ('id_3', 'i'),
#  (('id_3', 'id_2'), ('id_3', 'id_2')): ('id_3', 'id_2'),
#  (('id_3', 'id_3'), ('id_3', 'h')): ('id_3', 'h'),
#  (('id_3', 'id_3'), ('id_3', 'm')): ('id_3', 'm'),
#  (('id_3', 'id_3'), ('id_3', 'k')): ('id_3', 'k'),
#  (('id_3', 'id_3'), ('id_3', 'id_3')): ('id_3', 'id_3')}

# %%
#Check that all the composables defined by equations have matching targets and sources.
function checkComposability(c::Category, debug::Bool=false)

    for thisEquality in c.relations
        if !occursin("~", string(thisEquality.left))
            second, first = thisEquality.left.args 
            second = string(second)
            first = string(first)
            
            if c.src[second] != c.target[first]
                if debug
                    println("composability violation")
                    println(first,second)
                    println(" ")
                end
                return false
            end
        end
    end
    return true
end

#Check that the composition of any two arrows with matching sources and targets has a name by brute force
function checkComposition(c::Category, debug::Bool=false) :: Bool
    
    morphisms = [morph for morph in keys(c.src) if !occursin("id", morph)]
    for i in morphisms
        for j in morphisms
            if c.target[i] == c.src[j]
                simplified = simplifyComposition(i, j, c.relations, c.identityRelations)

                if occursin("comp", simplified)
                    if debug
                        println("missing composition name: ")
                        println(thisComposition)
                        println(" ")
                    end
                    return false
                end
            end
        end
    end
    return true
end;

# Check that category c satisfies associativity by brute force
function checkAssociativity(c::Category, debug::Bool = false) :: Bool
    morphisms = keys(c.src)
    relations = c.relations
    identityRelations = c.identityRelations

    println("Checking associativity...")
    for i in morphisms
        for j in morphisms
            for k in morphisms
                if (c.target[i] == c.src[j]) && (c.target[j] == c.src[k])
                    if occursin("id", i * j * k)
                        continue
                    end
                    leftAssocLeft = simplifyComposition(i, j, relations, identityRelations)
                    leftAssoc = simplifyComposition(leftAssocLeft, k, relations, identityRelations)
                    rightAssocRight = simplifyComposition(j, k, relations, identityRelations)
                    rightAssoc = simplifyComposition(i, rightAssocRight, relations, identityRelations)
                    if leftAssoc != rightAssoc
                        if debug
                            print("associativity violation: ")
                            println(k,j,i)
                            println(leftAssocLeft)
                            println(leftAssoc)
                            println(rightAssocRight)
                            println(rightAssoc)
                            println(" ")
                        end

                        return false
                    end
                end
            end
        end
    end

    return true
end;



function homomorphismFunctorCheck(functor)
    srcCat = functor.srcCat
    targetCat = functor.targetCat

    for i in srcCat.morphisms
        src = srcCat.src[i]
        target = srcCat.target[i]

        # check source and target of morphism image
        if (targetCat.src[functor.morphismMap[i]] != functor.objectMap[src]) || (targetCat.target[functor.morphismMap[i]] != functor.objectMap[target])
            println("Functor violation...")
            return false
        end

        # check homomorphism
        for j in srcCat.morphisms
            if srcCat.target[i] == srcCat.src[j]

            end
        end
    end
    return true
end
