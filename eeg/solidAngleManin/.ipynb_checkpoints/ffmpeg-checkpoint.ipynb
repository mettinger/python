# %%
# !ffmpeg -i C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/dipoleSphereGraph/480p15/dipoleSphereGraph.mp4 \
-ss 00:00:00 -t 00:00:05 -c:v libx264 -crf 23\
C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/dipoleSphereGraph/480p15/dipoleSphereGraph_clipped.mp4
# Out:
# ffmpeg version 4.4.1-essentials_build-www.gyan.dev Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.2.0 (Rev1, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sigmoidScene/480p15/Sigmoid.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#     comment         : Rendered with Manim Community v0.12.0
#   Duration: 00:00:06.00, start: 0.000000, bitrate: 26 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 854x480, 24 kb/s, 15 fps, 15 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000001bd409d2200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000001bd409d2200] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 000001bd409d2200] 264 - core 164 r3075 66a5bc1 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sigmoidScene/480p15/Sigmoid_clipped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.12.0
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 854x480, q=2-31, 15 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   75 fps=0.0 q=-1.0 Lsize=      14kB time=00:00:04.80 bitrate=  23.4kbits/s speed=51.1x
# video:12kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 14.286876%
# [libx264 @ 000001bd409d2200] frame I:1     Avg QP:10.14  size:  5038
# [libx264 @ 000001bd409d2200] frame P:30    Avg QP:20.59  size:   114
# [libx264 @ 000001bd409d2200] frame B:44    Avg QP:19.67  size:    72
# [libx264 @ 000001bd409d2200] consecutive B-frames: 13.3% 18.7% 20.0% 48.0%
# [libx264 @ 000001bd409d2200] mb I  I16..4: 81.9% 11.0%  7.0%
# [libx264 @ 000001bd409d2200] mb P  I16..4:  0.0%  0.0%  0.1%  P16..4:  0.4%  0.1%  0.0%  0.0%  0.0%    skip:99.5%
# [libx264 @ 000001bd409d2200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.4%  0.1%  0.0%  direct: 0.0%  skip:99.5%  L0:59.9% L1:36.8% BI: 3.3%
# [libx264 @ 000001bd409d2200] 8x8 transform intra:12.0% inter:15.6%
# [libx264 @ 000001bd409d2200] coded y,uvDC,uvAC intra: 4.9% 6.8% 5.9% inter: 0.0% 0.0% 0.0%
# [libx264 @ 000001bd409d2200] i16 v,h,dc,p: 90%  6%  5%  0%
# [libx264 @ 000001bd409d2200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37%  0% 63%  0%  0%  0%  0%  0%  0%
# [libx264 @ 000001bd409d2200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 23% 38%  6%  1%  1%  1%  6%  3%
# [libx264 @ 000001bd409d2200] i8c dc,h,v,p: 96%  3%  1%  0%
# [libx264 @ 000001bd409d2200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000001bd409d2200] ref P L0: 62.8%  0.8% 19.1% 17.3%
# [libx264 @ 000001bd409d2200] ref B L0: 77.3% 12.1% 10.6%
# [libx264 @ 000001bd409d2200] ref B L1: 93.9%  6.1%
# [libx264 @ 000001bd409d2200] kb/s:18.57

# %%
# !ffmpeg -i C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles.mp4 \
-ss 00:00:01 -t 00:00:05 -c:v libx264 -crf 23 \
C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles_clipped.mp4
# Out:
# ffmpeg version 4.4.1-essentials_build-www.gyan.dev Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.2.0 (Rev1, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#     comment         : Rendered with Manim Community v0.12.0
#   Duration: 00:00:06.00, start: 0.000000, bitrate: 35 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 854x480, 32 kb/s, 15 fps, 15 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 000002647a432640] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 000002647a432640] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 000002647a432640] 264 - core 164 r3075 66a5bc1 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles_clipped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.12.0
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 854x480, q=2-31, 15 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   75 fps=0.0 q=-1.0 Lsize=      24kB time=00:00:04.80 bitrate=  41.2kbits/s speed=47.8x
# video:22kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.727510%
# [libx264 @ 000002647a432640] frame I:1     Avg QP:11.19  size: 15769
# [libx264 @ 000002647a432640] frame P:23    Avg QP:16.72  size:   159
# [libx264 @ 000002647a432640] frame B:51    Avg QP:19.48  size:    55
# [libx264 @ 000002647a432640] consecutive B-frames:  2.7% 13.3% 20.0% 64.0%
# [libx264 @ 000002647a432640] mb I  I16..4: 65.7% 16.9% 17.4%
# [libx264 @ 000002647a432640] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  0.3%  0.1%  0.1%  0.0%  0.0%    skip:99.4%
# [libx264 @ 000002647a432640] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.2%  0.1%  0.0%  direct: 0.0%  skip:99.7%  L0:55.6% L1:32.8% BI:11.5%
# [libx264 @ 000002647a432640] 8x8 transform intra:17.0% inter:12.1%
# [libx264 @ 000002647a432640] coded y,uvDC,uvAC intra: 13.4% 13.0% 12.7% inter: 0.1% 0.1% 0.1%
# [libx264 @ 000002647a432640] i16 v,h,dc,p: 93%  2%  5%  0%
# [libx264 @ 000002647a432640] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 54%  6% 38%  0%  0%  0%  0%  0%  1%
# [libx264 @ 000002647a432640] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 26% 18%  8%  3%  5%  5%  5%  5%
# [libx264 @ 000002647a432640] i8c dc,h,v,p: 92%  3%  3%  1%
# [libx264 @ 000002647a432640] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 000002647a432640] ref P L0: 71.8%  4.5% 15.8%  7.9%
# [libx264 @ 000002647a432640] ref B L0: 68.2% 20.2% 11.6%
# [libx264 @ 000002647a432640] ref B L1: 96.0%  4.0%
# [libx264 @ 000002647a432640] kb/s:35.61

# %%
# !ffmpeg.exe -i C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles_clipped.mp4 \
-i C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sigmoidScene/480p15/Sigmoid_clipped.mp4 \
 -filter_complex "[0:v]pad=iw*2:ih[int]; [int][1:v]overlay=W/2:0[vid]" \
-map "[vid]" \
-c:v libx264 -crf 23 \
C:\Users\the_m\github\python\eeg\solidAngleManin\media\sphereSigmoid.mp4
# Out:
# ffmpeg version 4.4.1-essentials_build-www.gyan.dev Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.2.0 (Rev1, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sphereScene/480p15/SphereWithDipoles_clipped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#     comment         : Rendered with Manim Community v0.12.0
#   Duration: 00:00:05.00, start: 0.000000, bitrate: 39 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 854x480, 36 kb/s, 15 fps, 15 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'C:/Users/the_m/github/python/eeg/solidAngleManin/media/videos/sigmoidScene/480p15/Sigmoid_clipped.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#     comment         : Rendered with Manim Community v0.12.0
#   Duration: 00:00:05.00, start: 0.000000, bitrate: 22 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 854x480, 19 kb/s, 15 fps, 15 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> pad
#   Stream #1:0 (h264) -> overlay:overlay
#   overlay -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0000017115603ec0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0000017115603ec0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0000017115603ec0] 264 - core 164 r3075 66a5bc1 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'C:\Users\the_m\github\python\eeg\solidAngleManin\media\output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.12.0
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1708x480, q=2-31, 15 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   75 fps=0.0 q=-1.0 Lsize=      35kB time=00:00:04.80 bitrate=  59.2kbits/s speed=21.2x
# video:33kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.126915%
# [libx264 @ 0000017115603ec0] frame I:1     Avg QP:12.91  size: 20795
# [libx264 @ 0000017115603ec0] frame P:29    Avg QP:18.55  size:   233
# [libx264 @ 0000017115603ec0] frame B:45    Avg QP:23.69  size:   124
# [libx264 @ 0000017115603ec0] consecutive B-frames: 14.7%  5.3% 32.0% 48.0%
# [libx264 @ 0000017115603ec0] mb I  I16..4: 47.6% 40.4% 12.1%
# [libx264 @ 0000017115603ec0] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  0.5%  0.1%  0.0%  0.0%  0.0%    skip:99.3%
# [libx264 @ 0000017115603ec0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.4%  0.1%  0.0%  direct: 0.0%  skip:99.5%  L0:49.9% L1:46.0% BI: 4.0%
# [libx264 @ 0000017115603ec0] 8x8 transform intra:40.6% inter:13.0%
# [libx264 @ 0000017115603ec0] coded y,uvDC,uvAC intra: 9.7% 10.4% 9.8% inter: 0.1% 0.1% 0.0%
# [libx264 @ 0000017115603ec0] i16 v,h,dc,p: 87%  6%  7%  0%
# [libx264 @ 0000017115603ec0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 65%  3% 32%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0000017115603ec0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 27% 23%  7%  3%  3%  3%  5%  4%
# [libx264 @ 0000017115603ec0] i8c dc,h,v,p: 94%  3%  2%  1%
# [libx264 @ 0000017115603ec0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0000017115603ec0] ref P L0: 74.8%  1.3% 14.5%  9.4%
# [libx264 @ 0000017115603ec0] ref B L0: 74.3% 16.9%  8.8%
# [libx264 @ 0000017115603ec0] ref B L1: 95.2%  4.8%
# [libx264 @ 0000017115603ec0] kb/s:52.98
