# %%
# %matplotlib osx

import pandas as pd
import numpy as np
import mne

# %%
dataPath = '/Users/mettinger/Google Drive/NeuroResearch/data/NewMCPT1_wake1.txt'
#dataPath = '/Users/mettinger/Google Drive/NeuroResearch/data/NewMCPT1_sleep1.txt'

# %%
with open(dataPath)as fp:
    lines = fp.readlines()
    
columns = lines[1].strip().split()
data = np.array([lines[i].strip().split() for i in range(2,len(lines))])

df = pd.DataFrame(data=data, columns=columns)
print(lines[0])
df.head()
# Out:
# TimePoints=367000 Channels=21 BeginSweep[ms]=0.00 SamplingInterval[ms]=1.000 Bins/uV=1.000 Time=02:00:05
#   LT17-*AV LT21-*AV LT25-*AV LT27-*AV LT29-*AV  OF1-*AV  OF3-*AV OF5-*AV  \
# 0    34.23   160.83    41.55     7.71   188.24  -126.11  -147.18  -47.89
# 1    32.19   156.84    38.04    -0.39   180.24  -128.94  -151.47  -53.16
# 2    31.02   151.96    33.65    -7.71   172.64  -132.16  -156.54  -56.77
# 3    30.63   146.11    29.26   -15.22   165.61  -133.14  -164.05  -58.23
# 4    32.38   142.69    26.92   -20.48   158.69  -133.72  -171.27  -58.03
#
#   OF7-*AV  OF9-*AV  ...  LF1-*AV  LF3-*AV LF5-*AV LF7-*AV LF21-*AV LF23-*AV  \
# 0   45.65  -137.33  ...  -145.52  -101.83   -0.00  -59.79   -58.62   -67.88
# 1   41.45  -141.62  ...  -130.99   -96.17    4.29  -59.11   -48.96   -62.42
# 2   40.28  -144.16  ...  -105.44   -79.39   18.63  -49.16   -29.26   -46.52
# 3   41.55  -145.13  ...   -92.17   -74.81   20.09  -51.21   -23.12   -42.92
# 4   46.33  -141.72  ...   -86.03   -81.64   13.17  -63.11   -26.04   -47.60
#
#   LF31-*AV LF33-*AV LF37-*AV PST1-*AV
# 0    36.77   -26.24     0.98    25.36
# 1    42.33   -15.90    12.29    30.43
# 2    57.94     2.44    28.68    40.67
# 3    63.01     6.83    30.04    35.11
# 4    59.30     2.24    21.85    20.87
#
# [5 rows x 21 columns]

# %%
sfreq=1000./float(lines[0].split("SamplingInterval[ms]=")[1].split(' ')[0])

info = mne.create_info(ch_names=columns, sfreq=sfreq)
raw = mne.io.RawArray(data=data.T, info=info)
# Out:
# Creating RawArray with float64 data, n_channels=21, n_times=367000
#     Range : 0 ... 366999 =      0.000 ...   366.999 secs
# Ready.

# %%
raw.plot(duration=1)
